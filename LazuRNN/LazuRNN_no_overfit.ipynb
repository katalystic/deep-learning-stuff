# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.reset()
# Out:
# Using TensorFlow backend.

# %%
textgen.train_from_largetext_file('phrases.txt', new_model=True, num_epochs=50, train_size=0.8)
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 77,589 character sequences.
# Epoch 1/50
# 606/606 [==============================] - 8s 13ms/step - loss: 3.1568 - val_loss: 3.1322
# ####################
# Temperature: 0.2
# ####################
#   er      ea e e  e t             o     e  n   e he  e e    e  e                  e      en         e  e        t  e    s    een       t         t          eeeee  r eh      e        e    e   s e a    e      s    e            at a  e e     e t             e  ea ee    e e  ee   e       e        e    e
#
#       t o       e   et  e  n                et   e        e          h  e  e       ee i  i       e  r       e    e     r   eo  e               a  e e     e                 e    eo    te   e  ee                 ee      e     te e  s    e    e        h           e ee              o    oee     e      r
#
# ...

# %%
textgen.generate_to_file('LazuRNN_chartrain_settrainsize.txt', n=50,temperature=0.5)
# Out:
# 100%|██████████| 50/50 [00:25<00:00,  2.07it/s]

# %%
textgen.reset()
textgen.train_from_largetext_file('phrases.txt', new_model=True, num_epochs=50, train_size=0.8, dropout=0.2)
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 77,906 character sequences.
# Epoch 1/50
# 608/608 [==============================] - 8s 13ms/step - loss: 3.1550 - val_loss: 3.1483
# ####################
# Temperature: 0.2
# ####################
# e ee  e e   e i  e         e  s  e ee  ie  e e    eee   e a    ne  ae h es e e   e  e   e    ee   e              n          ie  n    ee one   e      s   e  e      ea t     ee    e     eaee ee       a  e eee e   eee e  e ao ne             e   e     ee    e          e         e    e          n e     e
#
#  s  e    e   t e e        ae   eo ee  es o          e   e   e      ee   e  e    ee  e   e      e      e e        e  e a    sn    e    eee  oe              ee ee  o ee ee  ee     eee e  e e     e      e e  ee e     e ee e s e ee e      e s           ee    eeesn ie     e        eeie  e e  t e ee e
#
# ...

# %%
textgen.generate_to_file('LazuRNN_chartrain_dropout.txt', n=50,temperature=0.5)
# Out:
# 100%|██████████| 50/50 [00:38<00:00,  1.17it/s]
