# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.reset()
#textgen.train_from_file('phrases.txt',num_epochs=40)
# Out:
# Using TensorFlow backend.

# %%
#textgen.generate(n=5,temperature=0.5)

# %%
#textgen.generate_to_file('LazuRNN_texts_2.txt', n=50,temperature=0.7)

# %%
#textgen.reset()
textgen.train_from_largetext_file('phrases.txt', new_model=True, num_epochs=50)
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 97,354 character sequences.
# Epoch 1/50
# 760/760 [==============================] - 8s 11ms/step - loss: 2.8495
# ####################
# Temperature: 0.2
# ####################
# alalulalalalalulalilalilallillalalalla lalallilallalilalalallalulalallalulalallalallalalalallalallalalallalillallalallalallallalilalalllalallalallalallalalillllalalalallalalallalalalallallallalalulalalalla lalallalalalulal alalulalalalilullala lulalallallallalalalalalalallalallalalallalullullallalla
#
# lalalalalalalalalulillalalllallallalallalalalallalalallallalallallallillallalalulilllalalallalaallla lullalallallalalalalallallaillalallalalallallilallalallalalalalallalallalalalallalilallalalalallalalillalallalallillalalalallallallalalalalallalillallilalillalulalllalalalalallalalalallallalalallalal
#
# ...

# %%
textgen.generate(n=5,temperature=0.5)
# Out:
#  20%|██        | 1/5 [00:00<00:01,  2.30it/s]
# ed you inheritow
# On the night of a full moon, it continued to be refined
# And the stone became four mirrors
# The people swarmts of this body
# A country acroked with a rotten haired was barks
#
# Ah, speing I bought his vilialiat
# The one who are together on my home
# He was a world with nothing in it, its ti
#  40%|████      | 2/5 [00:00<00:01,  2.19it/s]
# him":
# Will I am the choce to a parallel world
# Malming Princess, huh, bus, her over me
# The real you and right you anym, precing
# But the minister of torture her decorned to be refined
# And the seals stainer in the cword
#
# Everything was another who held a long ago, us
# And so that body
# This is a heart, b
#  60%|██████    | 3/5 [00:01<00:00,  2.17it/s]
# l but you truly on the forest
# I picked up red RED fruits
# These are surely wonderful, With this gift
# Blood tears spilled love
# In the end rest
# Lighted his heart has been killed
# ...

# %%
textgen.generate_to_file('LazuRNN_chartrain_deftemp.txt', n=50,temperature=0.5)
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.64it/s]
