# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.reset()
# Out:
# Using TensorFlow backend.

# %%
textgen.train_from_largetext_file('sanhora.txt', new_model=True, num_epochs=60)
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 613,898 character sequences.
# Epoch 1/60
# 4796/4796 [==============================] - 70s 15ms/step - loss: 1.3702
# ####################
# Temperature: 0.2
# ####################
# hhhihhhhhhhhhhhhhihur r   r            y eee heere  ha  :   shhere      ma mor:    whe          re tere athe reanWer the stars the fan and of the for the st
#
#
#     99Weshe     c  r     a  shhhhhhhhhe   e , Isher u me ere e ee eer rereiroeeeeor  er   / , the reant o,sshhh the   someW,
# sshhhhit  e c   e           w e
#
# oo e                end                             w  hhh    t thee       e  shshhhhe                       r e errr    60000!0   Isthhhhh e rroom  m   rre, Ishhhere  f Iflee
#
# ####################
# Temperature: 0.5
# ####################
# here Ih So hreo()
#
#
#
#
#
#
#
#
#
#
#
#  Thhhhhe wsa e thhroouth ahhhhhhhhhhihhhhhhhhhhhhhee hhrhhes omheru  i ome hrhie  hh  hrrroehhefh:Unchohhhhihhhhhhhhher cerehesthmhhhishhirs eho sheswhhhs , hhiW
#
#    yli  hoeshhhhhoou wheree  m WWehhhhhhenloor        u   , r  u rrrh    ~
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  it   l her do be athe ro emander of to skeen s hWehhhheshhhhhhe 0000Thhe
#
# hehhh ,
# fffff fr               rrerrrrrrrrlerrr  ester  se ccreenad: 60T0he s enn00 chhahhhsm hmelhhrerei w   a   Ifloooo Hoer, af we6Ishhhh&.werurir mr ry   ee
#
# ####################
# Temperature: 1.0
# ####################
# eehrerhanerve siloe hsqeft YugCp:
#
#
#  Thioshhhher,   cs c   &  )H oOoemorTThThOrhhuf;hhhh ], ?   ;t&et ,h h noei h eir c>whe1eeh hhnsl hqhheapalehthhhhrhhhh 0ahu hunc  OhBhutrtieOehnrhhy  oemhusehuehhk leratayt
# rer Th
#
# e eguv&&yueey&g e ,hhhgae renuuehcheehhhh hehuemh  n's ermtmlme  mheer
# 'tshn0  n (0H:  Thohh&&    w Imlson%9yb& I fute my,i
# hi asecht !as
#
#
#
#
#
#  I  Terr&,
#
#
#
#
#  ) hi   f eei
#  &hk lai  1Keef temiveroant&
#
#
#
#
#  rmey o  Y beor four)wahiniftt h& on  ~   egh ie ia iohdieeuuoekhi~f e, yhlrrifee!Fc4effw! cuitwhhh haiblerh areme yoeh sthrohrwensehnar a ! .h w&  w
#
#
#
#
#
#
#
#
#
#
#
#
#
# So   re w m eeIhn hathh spiely Ighef l0fie!)n dNiouf Icfhed nch tu,hwacossh
#
# Epoch 2/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.9158
# ####################
# Temperature: 0.2
# ####################
# tt an end the seem of the sunse of songs the seek of so the she said to the singers of the sings and lost and so the seek to bear
# 0The sings of the
#
#   te  ee and a l  seae~
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  t een tear the emit  the man to bez    look ithhe nn and death&
#
#
#
#  Hey and will not the sings of see and a
#
#  tan and the she to the sings of the sings of seek of the sings to the sky the seek of the sings of the seek
# 0the sings of she in the sky
# 0The sings
#
# ####################
# Temperature: 0.5
# ####################
#   you  nemy e sold you strees and I seek died and the sail of sings to many to same of the bearing the wingers and flames and and gongs in the long o
#
#   e-! our  e&
#
#
#
#  I~   Mill tting in the do now my being in the sings
#
# Ah& wear and the sings, the sings sorral as a
#
#  tetel, tis alning&iy a ride o the moonning any mornance&
#
#
#
#  I m so the seen filled and and she sarries, and now to the should of the mara
#
# ####################
# Temperature: 1.0
# ####################
# sc Ahr"& thhe tatrevereeralrlleru luz zheog eeexhpanheveeath nee connern y nown!sean any no hearbering&
#
# A frot morn&  rime, the same
# 0my& Was thank our toda
#
# ycte i zz& r~& ueelt tt&ep hiuaa m ri ss t!  jesn t & Eles, alrust a daughter seca&
#
# And gong cerive [the mirh] bothing [Cartion
#
# ,a a ez&
#
# &  <nwe? Sep! Than a world&
#
#
#
# Light I sirper to a sage in sefees being crage Heirad  in etern is death
#
# Bucting leftm
#
#
#
#  The
#
# Epoch 3/60
# 4796/4796 [==============================] - 48s 10ms/step - loss: 0.8351
# ####################
# Temperature: 0.2
# ####################
#   u//~e~/ii
# )
# z
# ~
#
#
# ~~
# ~~ehee  e neee~oe ee eeeeere taun  s treannnoLEminng atitusts winittst eet  eelveereenns [ha reenebre - I s1heoo1o I ffou on&
# &ye&yyishhtte rrtr2rererealllacl
#
#  le bunffffifiifssfvsffffUfffUUniUfsnfnivnifhniiihtihshhet~ a a tehouhhehhand&
#
#
#
#
#
#
#
# Hahha,
#
#
# 0Mr  teeshhat&  &
#
#
#
#
#
#
#
#
#
#
#
#
#
# / ~ t /e
# he hhhhhoooooooooooooooooooooooooooooo
#
# reagugnisshstser a   the ea!
#
#  Hwend the countage of the world of the connections of the continues of the frozen of the world of the continues of the
#
# ####################
# Temperature: 0.5
# ####################
# es0, I don'  the connecinngsss&   ~  /
# ~  cli~
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /
#
#
# /
#
#
#
#
#
#
#
#
# / L o&
#
#
#
#  Hahaaa&
#
# ( Charking the story of the countly and was this has
#
# he brings of the cangers with a things to the man stars be the days of the beautiful first and an our the fire the laughed of the mother everyone arri
#
# e& on tting and re0Newels0 [And] the wind of the thangs from the mowen the mother of her life
#
# And do you are you sun the world with a frogher
#
#
# ####################
# Temperature: 1.0
# ####################
# atennoren-anuninl l cthhautnn11ntunuy,nitthoo! da)&. Ea ~! eo ~
#
#
#
# ~n
# ~.
#
# (hh
# CHe hHere a ~eh  heHyeiheHhohtcrwhfishhhshhe hunnenhihst t h-w b pne~see
#  e &e ies othherr-a-bleMah uts  eeunen !
#
#
#
# (I Ne1n&  Ishen bbyestuuu
#  I want with you re reach birth
#
#
#
# We re now...  I m crutent ! dough, through it for you everyone drese of <Reflaufe>[proaus] bunnaty& let s repoteri
#
# Lar&  waint mysualing from the sptretal griels, zukic griftings. And the <life>
#
#
# 0A goble ways  Lot&
#
# The rosed within the <drumbight
#
# ( The trai
#
# Epoch 4/60
# 4796/4796 [==============================] - 51s 11ms/step - loss: 0.7994
# ####################
# Temperature: 0.2
# ####################
#
# Th stars the cage of the wind
#
# The courth of the cage of an earth
#
#
#
# The story of the wind of the wind of the courth of the wind
#
# The story of
#
#
#  Wk the courth of the world of the forest beautiful in the wind of the coration of the windmise of the wind of the cage of the world of the court
#
#
#  O!oooooooooooooo!e all of the windmis of the story of the wind
#
# The sing of the wind
#
# The story of the cage of the courth of the spine of t
#
# ####################
# Temperature: 0.5
# ####################
# the   vea teer eanotick torundwasiouselhessanni"I ...eeaun au Ial Lo)
# T rean, awahathhes loouato  Mny n
# !! !
#
# veearnte tc thorerr   quRHol
#  eet.eerh..   Oh
#
# e uroos of the way of pring in the wind of a girls of the cage of an azurr of her saddened my the story of first
#
# The world of the rouge of the
#
# l o  my way to trogones to the twin of chantly
#
#
#
#  Oh my is the world the moonlight a could be and the sky good my fantasy to seen the really tha
#
# ####################
# Temperature: 1.0
# ####################
#
#
#
# cs   Mmere etrysolu)
#
#
#
#
#
#
#
#
#
#
#
# Kinittal tamaa as Roude0lreou s  inee eeee ffnbnvoetrtethe hereiD,s worooiknn t looughes e  TnacWenshoy ee?
#
#
#
#
#
# eThhe  gy his I& &
#
#
#
#  Ha)
#
#
#
#  K we ll can a tomor harves strick, p I&
#
#
#
# "However the cast!
#
#
#
# Do you, I m like you remeived a damnoned mois her when they eever and gent
#
# has began arm?
#
#
#
# And you like you fely to paradise, to for your chuscion-
#
#
#
# (Pre:
#
# My ! forever ralite with now
#
# They me'll could...
#
#
#
# Wh
#
# Epoch 5/60
# 4796/4796 [==============================] - 55s 12ms/step - loss: 0.7768
# ####################
# Temperature: 0.2
# ####################
#  tttttz oshhhe hur es theired ereeeeKhehKteeveFFe0efTKflhs   evennce on the water of the water of the water of the moonlight of the water of the water of the w
#
#
#
#
#
#
#
#
#  Ahk thearre l  ahaunoos %..
# Keer0Kan)s  eatteR! locs lonid a and!
#
#
#  thee  aes the atca chhaly ateree  lt/yLs  %%ef e a thelVyrppynhV
#
# tathi an
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# iietreer reestePfe aretese eer00entatfuus tchs oMotHertlss -shior nnesauUt  suurwitUheg herely risitak&
# "Hand Raded by th ls e  &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# !
#
#
#
#
#
# ; a'shhs hhhsh0tearztalrnn szkks0nhtvne t1shssh
#
#  fhsjethils hetorKf   na1 hefi stte hed sQUhhs  Leat e lthhahoo  t hiek rst toy000malla ttr7r 22etr%!porits...
#
#
#
# A pivillain of the history of greetle
#
# of BRloeteers a trattherlis
# Houty nintthe nt Gotter ally call of tran/y  chhend RD tele&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ahahmthtees lthherrgitti&
#
#
#
# ####################
# Temperature: 1.0
# ####################
# -!)
#
#
#
# 5Hol
# A Rosnrlthtalle Rtey!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Isen lstfl, shake mee!YOmouuch War ot umpome aroun0 kill!"
#
# "Back
#
#
#
#
#
#
#
#
# /E
#
#
#
# sotmemlefistte lyd  ratyNThronng plitarintill lKtshhuldewneeeeerl ed thiatla9l  MZPonecttrnntuhtel ha"
#
#
# Thesse hhhise usshr hrerol ofo ex01xx.efpiea suuh7 teh   nBji the thhhhn7 thhhh hhesVs h  R
#
# -
# tahhes thh ah ty yeon thher erlee a sttro0n, hhhef tt 0stc7
#
#
#
#
#
#
#
#
#
#
#  Throulllls sty,o% aK therrlner e! Uo
#
#
#
#
#
#
#
# Thea s&sy7haumm moyeothisb
#
# Thehrn nanzuaanu bCtttsJua )
# Yfoooo hR
#
# Epoch 6/60
# 4796/4796 [==============================] - 51s 11ms/step - loss: 0.7611
# ####################
# Temperature: 0.2
# ####################
# frouzz MJoooHHeis  Liuit!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Ahrek oo( then! M ..
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Wahatt!
#
#
#
#  Ahahaha!
#
#  Wall or the boldr [BrouccyelFlhet0 atrunsk&
#
#
#
#
#
#
#
#
#
#
#
#  D jla& a
#
# P  EoI hk I ma R0ThherattelUReT00Jooenc0the(0 Thhe P00tr0o0only Reeeteechheeze
# o
#  Ahrealthct atYlonn, uhherUs M00Juary Drhoe&   Ratcte eryp   0taannn0M/ alllPli Pflyealllashes !
#
# ls:it jMand Realln OhorJoPfl" Wheron ntout! tare~eeUe~tear)&
#
# 0Thrat a.....(  Broutnalt2 ha reEZ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AroorJuh!  Ohorthhhhe&
#
#
#
#
#  Wa  OO, Ehe hatting th atth
#
# ####################
# Temperature: 0.5
# ####################
# Pere a!mahhanon
# 0
#
#
#
#
#
#
#
# Ahrout
#
#
#
#
# IterD  listtsC least RhQue
#
#
#
#
#
#
#
# Bu TheINN:uRoyoi2    KeJuofou, Ite ennid& t a thesnU&
#
#  GEtr"
# 0Thhe  truooyatt!0StKi  Rqo(   Youn nenneeez  ten&  thels t
#
# IAhn Ponflhlt! Reacooau0tKeh& aPHilati's21 Mr!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# q! I seems mother& on of the bring  yorizon
#
# The stars belie starrize to me a pow
#
# Tora  th r  ajehtis attrinn&&nFfKQQnHK1KFuKnP1tin 2Ret trotye&  nG.  Ift rpithintrA Js lje!
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Dhohnin !  What a world&  Stant of the sli
#
# ####################
# Temperature: 1.0
# ####################
# hatillllhhey M&
# 0thh00 Sco&ytthoPknciistet  tarea0trenla!Tol0U(she rtr Plstt"&thhothhenfBeus   The ? I bu0Leryher!nelth!
# Ro0T e
#   Th h- each! ffflKininte
#
#
#
#
#
# ornn atsTB ysQAAh
# , healllll !! hhenno0BEl
#
# u:huhhey her0o0vinrha"Y Kheeisot! y honnse l- Doooaot atte haveer  Ge!  0Ja Elily tals HHHKKJPeeleCHHHiKF Pent rife hnolD Plat ZJt hheon t&  Thennneni hitemaho! RJoueKiS  OBhurlery lwyaC P
#
# n&
#
#
# [Hantury! Rf0thherapehelM-tahhhtPe tytyuf  Ffouonea uh1ethim Sapp
#  Whor0Bryooinla
#
# I! RKenees1 fleaot lt  tThheiest skelatizndRhA Rhif!az yj&
# J D&0uA Rist geue
# GlyqlLPoolrey Eles: tlits....and<
#
# Epoch 7/60
# 4796/4796 [==============================] - 46s 10ms/step - loss: 0.7501
# ####################
# Temperature: 0.2
# ####################
# trong in tebeel as he &  treatst tn tatl
#
# Tea&
#
#
#
#
#
#
#
#
#
# The moonnls ntee elistzczzzzzzszzzzzFzzzFz1KKK1QFzsQPKQueette edotes a tcreee p  ttea2!0 to s edaLoende enneefueteery heal tPeiq0en
#
#
# Th  rooa
#
# ahahayll lt& onten1~  Uhthanh&e  u)  / /////// /;//y  Pf&
#
#
#
#
# 0Th e stirea  lethelt efof&
#
#
#
#
# Kinzziats iersentelied  LethhereoohmaU ; lisstsstK hote2liese frinL,tKieel Knness  teroene o000M
#
# lon
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 22
# 2225
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 55
#
#
#
#
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  notl&
#
#
#
#
#
#
#
#
#
# Thee KinceeeeeertH
#
# ####################
# Temperature: 0.5
# ####################
#  GeuGoeaonom...
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#  sht e!!kai2sis
# 2hi22 227 theroond Raseer0 MnchouuuuKuuK 00i00U20001
#
# 00Sness lum midne Stenlands
#
# A hkils at the attacki&?
#
#
#
# The beat of ti
#
# cHENN:Nh e  tathn nvs P z KP  R2eDK S 0 talPeaSseeateers!
#
#
#
#
#
#  e likk llhe: Kueu78uuuuu~eeeeu0"  KnEE70iS7TJunJitt0JHH)0oh   x&
#
#
#
#
#
# Lastee intinne atrmbeelshthau etu R anlN Mfosse..
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re beacumbrHihte ede ede ednebliitchHorLstHHei inzzaeayouhs)
#
#
# IWKeitt  theat t tt eiel=se l phle Usout hhha  anteded Keiln00tFenttoecvtU sgeno   E  )/   ''   it!  nsfoor  the jufc
#
# ####################
# Temperature: 1.0
# ####################
#
#
#
# But& a realooutce as not on <worsshes> downding, awake away as the rossed by conder?
#
# he world was don't worked benead by become beging waiting
#
#
#
#
# o tce thKy   CruuzozMKzzzzQzzizye ez20mseau/i&0~L/(qy cnta trountteless-bytrrurouhu( o&U...neinnc YoWon.
#
#
#
#
# beltGes e nigs; swining bedleauHHefy zencote edlldl uheaehOJfeoe. "
#
#
#
#
# Heor iter adweerhaLolKu. d shats Kn E>04 -indk , leitt e  athUn no, Choon reattec 8 emabcl t / Timant matanjubeecfff senernocencelnass R,e!
# aK
#
#  Seel0 [boting] with n
#
# Epoch 8/60
# 4796/4796 [==============================] - 46s 10ms/step - loss: 0.7399
# ####################
# Temperature: 0.2
# ####################
# Gel-l L Peauu?ucfn2f f.R no7000&)
#
#
#
#
# Juuunan&nhihh lhstjoon Ms au000000000Thn be 000iss RDinc Rlhts t9aa P  Let teerr  Heoon atn
#
#
#
#
#
#
#
#
#   A Rhazzash22aht2a2asa211nathre&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Myount  s zzzsze trooattites 00 R3 KMan.0.0 R&
#  I rols a hee& ant ReaD n hi &
#
# auuuuuuuuuzur~u~~ jz/a~uh00lzzu0R0 Thuq\tuuxqeFquFFu/uhuuu 1uuuFauu-ZYYoounnlRea bblsheethhhex Mminnep erh
#
#
#
#
# Tuh&
#
# era  !0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# quuchtht a& thhKnnnnnnnJunn ti0 ist0Th0hannt )- I sthoutn;n ittthttPYYhnesP tnh Ra0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
# 5
#
#
#
# Thho  atrtiritshyy00Tfost beotochle -Io
#
# ####################
# Temperature: 0.5
# ####################
# Ahh thhe scid heinnolhhathe jua&shsheveerl thhhthit tblethos MVRaaatGe -1
#
#
#
# "Itehit  anne somees tlithha0P0ot  &
#  7hoon tjunenndladn tct an bereaquHeajuLadizu")
#
#
#
#
#
#
#
# eThhYise temnes&
#
# Ah& I hhin, sell
#
# rcirall s.
#
#
#
# An.....lahhultus&
#
#  My list end ladl& rysh?
#
#
#
#
#
#
# %%00000Thhoreersl aza j~&
# uuaL Rees!z
#
#
#
# reeetepe L Veit thorjuZhees mo,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Binn)
#
#
#
#
#
#
#  Realllln ta
#
# oro RThhhhordeved thhoinn ist000  otet& thhere Ki
#  ejuneest hony ahsethesheen RKeeDpK  &  Itho <RNseer, thhe:rithe.t
#
#
#
#
# e-lwassa)
#
#
# Knet  the RThhhoes E00Scuupn &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fooat
#
# ####################
# Temperature: 1.0
# ####################
# aU.Do.& <Thh Veacttttb  a etchorsr: LU- Mo boY!vncyihy,
#   0Quuu    &
#
# vio0 Auuuu?culh0-Tho Torongissscorang .& heanle  thherd&)
#
#
#
#
#
#
#
#
#
# ExpiclochyhEitl, 2rI&
#
#
#
# Tere!!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# f
#
#
# lezinliy mitntrroon&
#
#
#
#
#
#
#
#
#
# 4thheer3  scinQuuhas tstret) s& ,
#
#
# -M[l Reabilyh
# "
#
#
# Onhhhati thearsteis a swaychte0Chcluth0quee c
#
#  Ma h0Kquuu&.y!
#
#
#  e! ILsnnn~(Knnnencnxc1 harnKeindJ0 RF1
# =Ah 2ahgausasnDoullllMthsb
#
# Ven&  Roooki eor th  RevF tumnin3&) 0A as,ilan&  P 30[Shourn)
#
#
#
#
#
#
#
# B
# on!
# I erxxkl evmyEllpitietcheREeOvar uV2uu&
# /y
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Awher&  ryoaa  t usn Ki ot&
# e samir  As he re!
#
# Epoch 9/60
# 4796/4796 [==============================] - 48s 10ms/step - loss: 0.7307
# ####################
# Temperature: 0.2
# ####################
# e ta le y fou .i0 tanol lelo tnl lecshs tal ttjueu he Kiiean...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# F
#
#
#
#
#
#
#
#
# Thhoroad itwee  thheats diselfM tL Ra j louquuu0sss biutH!
#
#
# Ely somin the sing
#
# Thhhoroourht  sthronnotsa booreess oo sthird&
#
#
#
# I wonnny 0The Story0 [the] Thound ofrejRetazzhhcca3caucctc20c3e1PnK0nnanhg-0ohhVoCPffura GitD biles
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rau&
#
#
#
# I ll be tcKneeeefe Dejjjj0j0 o HahT&
#
#
#
#
# Fo0 atins  &
# roshith,  <-KOUnn Plll(ay louselEuu ls jee)c L lou   ou   s &4 &
#
#
#
#
#
#
#
# I wase  a  , Rs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# nnoo nnex:e, Pltnlisty iss fout of& fERD elHHoehschhhERHQulu0 Sitmesheleintye
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Uettemmint&  7 99 999 9I sitit taslas -rounngt sjoeshet  a' /sshiTe&Zvenou%qKu...
#
# The
#
# oyy&.  Hel & homlradmy &  thero!!! oeonnat    0theast l"j
# et 0all beeau)  ILesht&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thhoath isseRD&
# I th I & Leas hhhh& tually0Bleychhe , ReRH leaEN lTbook
# f
#
#
#
#
#
#
#
#
#
#
#
#
# I ll be my words   Can a story be believe on the scarlet that was now to an eyes of the story of the singer of the warm that child the real of
#
# ####################
# Temperature: 1.0
# ####################
# n  tivemr
#
# I ll they a fumber is its only illa is
#
# I love you..
#
# "Words to the conscely stardust even of for that placing not me&
#
#
#
# One your f
#
#  ThKanzaahountse,
#
# veoof y. .. <Thoommigoleveeeheeey  Ne e nttentkh laitt & eencohee7d &s
#
#
#
#
# ISSSooM FfaUre. Eliest'shuzfit a.
#
#
#
#
#
#
#
# Pafwe lykbu   2n !!!
#
#  -meamJui& U& .LIOsYa hhakiikn)  ./e.. P0
#
# trer  The joompea-0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I f stalispes
#
#
#
# Nounfeor  ..Roun yrh rf nuhrryea,  ThseR al ys toct& tohLy!
#
# G
# ?
#
# vep it perp wsking thei deslesis zeho!   7)hu ge ZeZqeuvyjuec& fsuf.
#
# Epoch 10/60
# 4796/4796 [==============================] - 58s 12ms/step - loss: 0.7249
# ####################
# Temperature: 0.2
# ####################
# phte for eatchs&  0/' 'lashu0TQu0 0 toulel 0B&
#  0 Rosavroyely Ely0eLRDa\0 Plast! 0Plolla
#
#
#
# 0To   0ReouthregrhtleetPls j&a tlq&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# les are the fl
#
# ElVoutChhel Marodeell MGerl...ro, RestWeele0 [Stahhatffisuesh0
#
#
#
# un R0Ltrooook e0 Lotting ! thhoronul, theeRssies thoroGoke Seeebs beloves  %nlad the moon.
#
#
#
#
#
# UDR7veeellyas une 0Thheraccsoouortc0 l- RaaG)0....
#
# 0The?Iffr: Rfafs n  RDeT%a Ma t0 0Thherjeeatees frouBYYMeo, 0  Th l leed fl HrKeenond0j&eo Bechll 0ReDRsDefeel
#
# ####################
# Temperature: 0.5
# ####################
# n..nrE Mj REntnler0 [%anttifootche!
#
# rat maki0&
#
#
#
#
#
#
#
#
#
#  Really whit the bonder who died of the land, the fieted of so I was a sand of my really chan
#
# -
# Um, Reafiser AAhhun0 thoroRGodn!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Staqit&
#
# 00The quahly Rhootechhe RPls)o0L&Ei ra&.  G0tahERD%o.0 fatwinhehe?
# 0ThorEKuuesRse\haehechheetetdRroo0Bl DRYLI M
#
# la, Plhots& Elist&
#
#  R0,K l  NO, MRlquus aDaceakit siodddell0 the0E pssc<each lst0 [ElisstaDi! Leollvl9el70cef C- fl0so t a reemteeneded !
#
#
#  Weed l enveeurnD
#
#
#
# 480 lifBo
#
# ####################
# Temperature: 1.0
# ####################
# , 0effestesatu  [totfi, liteje l  ) riggeg<4
#
#
#
#
# <% SDeeessoq0fly, Reictehthhhhyerroer eweytykein0c0I sataqo!! d
#
#  Preyte fefoutu L)
# pn. laut thhorongtt*teoeEl a tir-llas&!zo7z79es
#
# 009 Rfee
#
# tos altu0zQ/&.
#
# 0 )] h0&.EA0[YigsehestqusJF0an Son00tra "Unn&btinl03Unfs&tfo feoolHn treat anddins their girl,htreenget in his duevea?
#
#
#
#
#
#
# Bless as teKnenwoe:xKnngnn1nFPFqnee
#
# u deamulea!: hurllacyouruzee  qeusnely,&! E
#
#
#
# St melltucep
#  tere!  rac-eftooshorLB Vsh pizty0 [AhJ  Slease gBeverityHHHChsetas7ut!iwnoei!? E GeVy\0 Temllbt77<lmb the! even llarrK nfe!!i
#
# Epoch 11/60
# 4796/4796 [==============================] - 56s 12ms/step - loss: 0.7177
# ####################
# Temperature: 0.2
# ####################
# 7 0thhirV Neo!oos Gil&)   <Raullao&
#
#
#
# I sannt to the& an in tere to the quiveencels.szQuug  thh040EleammitRQuyed ! Rus-
#
#
#
#
#
#
#
#
#
#
# 1
#
#
#
#
#
#
# 1 Wahhuhhhhk  ). &  Isuuuqon 0:0u0000Sta
#
# s thheinnn eeles torounghht RKereeej&&  /00 Reacoeos DINN
# NbN! Forootcanthheitysh foacialeyh thhes4ittsshh~oo linghht04000Thhhoor Rearn00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  WKnoooooKnnnP qetnlU0gh/ Myn000thoroDHH
#
# &
#
# "No&  Issn likDe as:
#
#
#
#
#
#
#
#
#
#
#
#
#  //// K7xG111RJ78o is1 treeaalll0  &y -
#
#
# 0TOrh  Recouo0 twinthh-wa Q!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  DSSoor(1ej DReeapReePf& I &suquuigie a hah chttRone a hhhhh-
#
# ####################
# Temperature: 0.5
# ####################
# RRe
#
# Mif&
#
# I 0 "o youn~  my mornit& -Avicseny the Emis a  /
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   tquun~  I Ra& !0Thhhoso0 Fia  .   .nl&  My whhhoorsnueor-l  !Fish!0Trex 0Thhe
#
# 'tuqu&)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   I  0ri: No& anq&  //7K /L'sst/KiiZea7a0li Ntquuuchheh0MyooGooQu &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /
#
#
#
# Aa
#
#
#
# What ta   Waitong to the oj& /; ///e~erquallyl&
#
#
#
#
#
#
#
#      Wh0 T0Reauce&   Keeep louns ttethe00& thhoro0 Reecvoelseee taly oonschhthheiPfe0juc ha&
#  ; R lif)& &quqqquq/buuqPuFFFuPuFu//ente.n , RYThhhhhio 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /
#
#
#
#
#
#
# /Z1
#
#
#
# ####################
# Temperature: 1.0
# ####################
# //  /maa.
#
#
#
#
#
# I under an old of one will revon through on the fine of the forrattle, yested her lovtips?
#
# Even if we sasch hy eyes&
#
# It is your hand
#
# '.s R000 0Thh4ro,bou varedM
#
#
#
#
#
# n~-thoon, knost tel0Dy& IilzMentoeu:loonannSct &)
# f0 C GeV  Ea0&yER&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /7KKKK KKx/KKP//7KK  2Pees.oesty::Ki le
# G
# Cq" Goyo&
#
#
#
#
#
#
#
#
#
#
#
#
#
#    WKheepoaoteoo
#
# mKchahheK lrni0&
#
#
#
#
#
#
#
# 4 v0DI004000lb h,ere&nqa,  K Renc))
#  0& RN
# NG)djM~RPE(TUPo0 0PoP1e e &  &
#
#
#
#
#
#
#
#
#
#
# Thhe dck  la&
#
#
#
#
#
# Whoento that-
# WaKes storo\b   RecCt;s MaThhhhhasnPs
#
#
#
#
# Epoch 12/60
# 4796/4796 [==============================] - 48s 10ms/step - loss: 0.7109
# ####################
# Temperature: 0.2
# ####################
#
#
#
# Ela liK  ev a s Reegela4lyy
#
#
# Roeb lithshhhheGo lebleef (f lossntPt Ra Reesu(  ria00Thheousors)
#
#
#
#
#
#
#
#
#
# I lIR! I Rbu RaDERhE-Kaii0ein / Ohhx& thherinkG l
#   YYYYYYYLe0ouKnxSicnRO[<hVs leie ta owan
#   )
#
#
# W lazlRi, liskiyy esfinl& I fa~ju: "Thhhithorn allis Yeijn &
#
#
#
#  I ye& I fi eninng llF1Elsy fr~ Reehj, &y0Thhorooceerererreanln
#
#
#
# The0T0herores& lood BraiLsD uj snsss)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ~
#
#
#
#
#
#
#
# ~
#
#
#
#
# ; YOn000 & & le~&
# RosaKnFSFUhYSrhKSne skiSi RbeRDRed  &
# "W!  Thhre&
#
#
# 0Thhoresh I ladnRrevees loutin RGserGacne28- )0
#
#
# ;  RbUffffffleer ! Rea]&&  ///~j/'/e''/' //y/1'1KK K0
#
# ####################
# Temperature: 0.5
# ####################
#  Reedjye:leasheBl-0Thh0LIshstels !
# 00Juh0itshhyshhhhQ3uJ0<RROhoGooOl]  f awn&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
# 0
#
#
#
#
#
#
#
#
#
#  ta taiat letDenls&Ejufon)
#
#
#
#
#
#
#
#
#
# The  side& I Und\Kier...
#
# A -- IweR
#
#
#
#
# K~[mahudaly 0Ki KK~ SninstS Mnit& alyh atrruheo0PhlDyJs.0 Thheho& stlaznaztnfruf3--Ki llJRKei  Ffle& 0tat sfols ju Recrnend sad ojelucr
# 000T0hee RiMbe daynl"QuAlh&
#
# 0Tro, Bof
#
# Iieess& IthhSx-&?
#
#
#
#
# /yKiKie:xKnsittteesE xx----R; Relel00DyK7700Qnff re filsealr0 itbro&
#
#
#  Ahhu~ lit lyerol- Doz,0brmvi0rol"00Thhereest  KShy e/yKnKK3KK1KKynnjiKKnnza5l50DHHse  ctan  0shhoruman"3
#
# ####################
# Temperature: 1.0
# ####################
# owrz, what fly sky at a is a night is please&
#
#
#
#
#
# A does reseverdasy and bitter& with no young but a the yarkGimpal& way
#
# His reyen man, the stars gi
#
# &   looooos-
#
# We, sookinn tiriti ,Rhns kniPifsei ishetRElves elyRc s/x&z0eakcnn&
# hienoy&  Rheheace!0 touykiesc.
#  Yboiritlfi HD Rifi0ob&
#
#
#
#
#
#
#
#
#
# I(lJJAma( lo& nlo l,Ben!rM
# ... Is &
#
#
#
# &  %..
#
#
# Thhoe sce &  I wons0Q! ReiwcekKK3KeeKeS
# 0MiE &
#
#
#
#
#
#
#
#
#
# 000Theoltct  rs, he&?
# Wl& wereever shat   Mr&chyfly eve er0sci(T4Tthhes/cyoo7ool1 laugh2b tallshh:a4!Y buhhekiitts l
#
# Epoch 13/60
# 4796/4796 [==============================] - 46s 10ms/step - loss: 0.7044
# ####################
# Temperature: 0.2
# ####################
# terhx  Let l0a  louikino traf tantenraveeeRbereerYeleLe elroouKyit  Prdilt toelyGEi   LIV REnbeju-------
#
#
#
#
#
#
#
#
#
#
#
#
#
# I
#
#
#
#
#
#
#
#
#
#  ---KnjR0
# ~~(aznChLenzi00whieUgonnnnshQoFERRaU1GNq0ueQun~  Knene00n000 Tnhoethh
#
# &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The  Rb thhoo~? Kinn)nqg &  T )(louwt  anteinng gwKdRD<KnKeeeep batean al0EliyMVi UVid a a~j/) /0KKn7 Knn/Knne)41
#
# \--KGE0ERENoettc ychhVIEV000Qu-bleieneW" <ha ddtZonn)
#
# -Lount'.sthsQlies00E0Elifet0 [Thattronac suchethiengsLe  Myit is tra& wist 000BEilsethenl3scooma him&
# & 0Thhe Swiqu HYyiaushhhhh Ressthhhhe7lF0Tu:KinfU:x tr shoio&  Goo Thheire of th  Thh
#
# ####################
# Temperature: 0.5
# ####################
# setrse aizeak ist be&yh0Efilce Pecoer0[mand MYPfoor Rruntyeiads o)
#
#
#
#
#
#
#
#
# 0Thhoir) awisngehoMittrs 0Thhoedid freies !
# 0
#
#
#
#
#
#
# Ifullly is the wateers
#
#
# field water fess...
#
#
#
# The water
#
#  licDM as&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Bu~!!
#
#
#
#
#  Noo!o on 0 floywingelsedy bevexifoierLtccaolye:n n tiitinnn!!
#
#
#
#
#
#
#
# Thhen beterren atryel EexGoou)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  E0 Caxx psedrus.
#
#
#
# 0&I ThYYYYoesox0Qu--
#
# ly, Mit ROnnta ajunstel Mlausht shQ!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   I thetterth atronifiin and Drcrnevssscc0Thheroicr sxAquu00uu4%e  th gie steunnts ass <KniitsFKneKY KKKnKnijaot, taitohe!!!
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
#  thee sio,Yuj& I ahaffy
#
#
# Ahbititedct o wsw wittf fo "B2ife o rcpl tittanndn chhistshnen&i00 ShQ
# :  Elo quineysh
# 0Thhoychsco Milterwhokzista)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# R-l lj,2 N,sel//YQeuV/vvQ.se0\h0t 'sq0
#
# mastur: NGEjRRRRRjRRRRRRReeVR#R* Yo s[CHHe7sthhhe eaa00 Setoh&ncjole0 []
#
# UnndsRbuu&l&ll#qsuar DyEl/ Ma BshazersrAmingtuns "& unhuhhVKnenc /xj;TVnc[ik&0 ayyUfefK0eQ0fMMbergotaque!!0 bitutam. Thho
#
#   )
#  .OnJJookknonndNJ0EdRsco). Fe
#  %% Thhoki)o
#
#
#
#   0NexxacttreatnUt:  chhatIvitzzzeeuerat graue, PellMCRWhheat H! 0ThhKGoreeteer agie "
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  \xapiste insch<scleuiteDe stea t ootyQfrezzey  ya
#
# Epoch 14/60
# 4796/4796 [==============================] - 49s 10ms/step - loss: 0.7003
# ####################
# Temperature: 0.2
# ####################
# 0 Thiee zashhhhyins&  KKiS/[~["[jS/0s[000 % Theas  YYoommtch anqu MNishtg4 Qi, l ear?a
#
# 2
# 1T
# 00E !"HHah elil5-G)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thho  iquentwnnsckcJucehZ Jehe:"Qur~/E1ii  tho&?
#
#
# %
# 0The seenk sh
#
#  GERReeeeo
#
# Jueisha00quuusl: OKnnOfn(f:PDUff0JPfctU0fDeequ/xquee...)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Be Thhoracqu  My h-
#
#
#
#
#
#
#
#
#
#
#
#
# 0Thee isshe ishedy O KKeKKKin  My hmoke !! !! ahuhhhhOaJla0Ne& Mao Mi...OnfeSS MVI VEROho
#
#  laloueTh is jeenched flwes wwas a shadow of myery an she who couldruzilas thihenS
#
#
#
#
# Mandishcqueel& 0quuuj~0hou0SSh: I HMiizzze7 er  o, Marianteryc GE/il/ '  quenzinzlMREhieettr NidGEest0quon~S%
#
# ####################
# Temperature: 0.5
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a
# i000stil0skG e nnina Geee jeele lietihsjootions Or- Jounninsthru Ushht4Pilll0sah GER;000 0T00rlethel)
#
#
#
#
#
# Ju ge:e  0quhhhhhepel ePrUe(07 RQE00e0000MEla MDOMNO  0readl\-Knnnnnn Q n0EGEP/;R007;
#
# a'shhhhhehhuhllR- ROeh0&wvequazzzzit thhhhhhhhe2Kly iBsent leiverves heroo0co0o&?
#
#
#
#
#
#
# (Thho& I ljeenzzeu   /Ni//KPy  .Ohha.N1KS1CKLR) x[BDJeShWneiees jeeethhE]  INOOOsqEuu~ Equ!
#
#
#
#
#
#
#
#
#
#
# JJueneme0 waaDB-Shaatlee  KOKUCKK
#
# n00Theses ta//'s'sh al0Mi/
#
#
#
#
#
#
#
#
#  Thr enis a farIMil Plishhen&a:  Flihe1ear20n'Ls a thohsshqe& L Eovey'  Pleaetioon GEReitoys& heavit e a NO1O&
#
# J % rooll-le& OOOOO0OOOKYSSSSVShSSeS DINGGG Arl
#
#  Leviti
#
# ####################
# Temperature: 1.0
# ####################
#
# LIl- gr  soazll  Dy&?  DRouCbHeu:xT/a''''/KR /727 R 7@7 Zj=i ndbunt litsDes
#
#
# whee fleivs ?"Qu0 A-Ra &thhoes thatles laltht G0uealt HMoa&  hahilasieteKy  /yKi s MDReue tieal inncs:cI
#
#
#
#
# T tr Ri" di-nis
#
# hJFY; lelVEl0wweai4talP)w f0448n L9    O0ha0ll":, INQis &. MishhMa rogusp!!!"  I lllDd innYvauzxhuqeu~~at 'y7s~ I.0ri0&  TheKGerfeststsese:eeu:7 K3
# emn  l ite ffj)ar:0 GER-00Threace Plist& tElis&   DeVyENio,t7 ltni
# thy\T%baset& shiaz n&
#
#
#
#
#
#
# J
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# J4
# 1 6t5 M via ll0 sqlE  ~!/ StGeavKK3qeqKuKUKj/Ki23K2Kil0al KOJqjBuKF4iRa7 Rej&?hhenir a 7&! IShVISN!SnteaiutrK pQ/d: ea  cs/~c: O,/2 lash/ycqu Hine&. ISho: )(Thhihatu0) wis
#
# Epoch 15/60
# 4796/4796 [==============================] - 46s 10ms/step - loss: 0.6938
# ####################
# Temperature: 0.2
# ####################
# hHee
#
# Ol0sroi  liek int thhir0eveziaequuachhaRxV!0m0is
#
#
#
#
#
#
# 77H areon eanzo0 Dayiall the sachely leeqHHa
#
#
#
# "ISn 'th sie n ncquetquo~
#
#
#
#
#
#
#
#
#
#
# J
# V"theaH
# !QuRi0j0uclea&
#
#
#
#
#
# qJJ Juuf !
# 0sitG
#
# Weenar-l IN) sootingls ischqiallele, Riaht4K!   )  0 Rexie&
#
#
#
#
# \-C--KPah0
# 0Timl0lawwe re thats sos  askiitt 0s0 Blehex ! ERhyawneasq0usal0j& Eq?a T
#
#
#
#
#
#
#
#
#   REeHies&: Wiht & thhiora
#
#
#
#
# Jo&  &   ; N  0 EqazzzzznnnnnP\2K72Qq57  q      Reve  q eyia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# J0qu00Don eisetNV ENe  ))
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Yosaari Mis: Wheeftsis!!"
#
# 0 Rxeac)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kn) 0Queae5 a scsoood
#
# ####################
# Temperature: 0.5
# ####################
#  &   /;YKvKKSK PyisOh x-Ril  Riacey&)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Reffrea,Nd& ~qute0huys! ! Un reQuaps! ;  " /KyyYycDZPyj<PSOiqiu0qunciha ymi&)
#
#
#
#
#
#
#
# J
# Jusee?a/y if yia's &   ..
#
#
#
#
#
#
#
#
# ~
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# z0unKf69 j
#
# 7J  R0Que &
#
#
#
# Qu.. hhori
#
#
#
#
#
# )
#
#
#
#
#
#
#
#
#
#
#
# A nNooR. NOO, Elick -
#
# ~ Rob&
# l l:  thhit thhonok stapshs, liapshhHHHHHhsinny0 [liedyKxKnc)StS! Ruc!x)  Recel t aR-Cok" //~/qu/uu~/uJnu&idie)
#
#
# We
#
# 0Sta0Qilamil&
#
# fallls~lyiesncJe/~~ T&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  A righhitening to  azure! o and i &  Reacoezal00Vaaaulattxquo Ep: ReacJeeaaJ0que Na
#
#
#
#
#
# " GElyhHVun eroingees:00Cla  ait
#
# ####################
# Temperature: 1.0
# ####################
# Q tte ciit! Uu.bladianzzashshenyb0-
#
#
# Jj&;Kaia~yin/ytu& ..~loavalrihillle N! Reuc etnn &  Razat!
#
#
#
#
# Jan Gin
#
#
#
#
# ( Theac/;YYYN)".Wasey EEbf3 GE eechhhGeeo,Ej .E  Elyoo!/i0ou  &wtubykGyKKR0KiRK xxi .
#
# n9
#
#
# <ex
#
# a, ftreaveeest &
#
#
# reive0 DHHeel, E MajuU, Dy yly,  itse0 DEliee unzboitsahan<eazQc0qo00(0Thenild s77axxx)x hqu;Nazz-<KbSKsunKeKP-ejUNe0hsnnqJelKKL heas!%! UaRsevqoannisK
#
#
#
#
#
#
#
#
#
# Kie n( dRz7K7eKRet 2a7 si
#
#
#
#
#
#
#
# oro!  B DIR.
#
# Mye  illct qath& 0byachIn0&
#
#
#
#
#
#
# 0athhoe leadault eveal  Beseapeiitse)<obo ed yl ReOl illis%
# 0
# 0
#  relene, Rexugucn0oe~y; Reetthsl o
#
#
# ")   Riditte statchrookoinngJ))
#
# Epoch 16/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.6891
# ####################
# Temperature: 0.2
# ####################
# iceat&sicbKRoeaKqJeugchhFJeUnc[1[UeUHmePO01
#
# UnnO  ahistKninnPt2~J0enc2hrHearschon GEl(&
#
#
#
#
# On, lonnd  They l0IN~qEEJJ00 Bshont C-ra0i7NRL7et]N
#
#
# 0 Tna  000TTa Miy
#
#
# val" teberryesthhhouisKths l e&  ithhh SSouiahhhhh
#
# e Re q&.)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Knooot ehh&    istRNKf N L0
# Ohha LLest)L annidolyyt racel0 Mlidilti Mi Chan&
#
#
#
#
#
#
#
#
#
#
# ...
#
# Lete, Ehhurblithie&i...hohowKnineshe nni-
#
#
#
#
#
# Thheriul E l 3 0\ Kn1)1 1at11KieQ<\Kons/quu~;R/;x~;~K;NV
#
# NO Ritelele0ezu. z0oushH&
#
#
#
#
# Thoorschenn''ww''s  enoOnnUccqxkq TK H RO&
#
#
#
#
#
#
#
#
# ThheEnl rsje: too~qutely the hy Thhra&?
#
#
#
#
#
#
#
# younfe liN0  KyellM3la3
# Mnma&
#
# Thho)<bolynlPffNNR<sNRactehb
#
# ####################
# Temperature: 0.5
# ####################
# <QKKGO<UN<KOx<7    0Thhooo zzze\lion~nquhhhhhou0!
#
#
#
#
#
#
#
# IhhKS~
#
#
#
#
#
#
#
#
# 000000000000000 Tr lads handlonl d LYYYYONOOcvvOcqcqqKqvBqn4n4nKqUUUZOAKU:Ki[Bledo&  The qut&itl
#
#
#
# Thhirorost the  os the oldeig
#
#
#
#
#
#
#
# Onlazze a rivees: Rece  Cs:e0;<it/77KeK3caiK7iK[KUieU0KaaeeK ejn~n1Q7Cxi/7;\7K7CH7SCKRiR4~E  Ch:  OOh& ViviasoK lioii ainnzznac0lalall1Umey0 ThahriMHHe lye/z?e7a7qo anOcthq Ke5eren e/y0erx   Th\ithKy aqujhu~1
# 0tquceieveedeKERe l0c
#
# E101
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# T
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I am. ElillalM MO Rreal  YYFejeeitu 0/ La&
#
# 0Thheocieem thateashhy yooson&i, Kinnequ/ququ&onn ~!)  A h& Ibsk<neniiele
#
# ####################
# Temperature: 1.0
# ####################
#  Go ERexxxy4 ldv0RH70&
#
#
#
# Thher Reexi..
#
#
#
# Theeriezezyie3 & Thhoroicit
#
#
#
# --CatmJea  tcu l&  Chaynt 3iaah7hqly
#
# <funj&: T0 Rj
#
#
# 7SChatiean.) -Re tuwwo EDERRevexlsy FidMo
# RiflhPoitgiu& ai tthV0vear l&
#  I  Um
#
#
# bst& & laive: O& Lasipllyb Phiteffu)
#
#
#
#
#
#
#
#
#
# ThadHinonoooktmhq ERitho,KnES/Ej/nV0BKese7j0IKn7[RND~0---
#
# oserll INV<   soueeQutreqEuxeDEGEtl & EilltewKei1 doillev erle lg,cQqJ.xqtuqi0&IEnJERK)... liishhy: wNGby!!
#
#
#
#
#
# eusue/ ~vy0Fo07S M Minzao2zCKSSR7RQDK72RKu7 4e& lavs)(52
#
#
#
#
#
#
#
# " KRQuuuuu;? a0 a ququu-hh& thhaux)  0 Twhhi  Pkhyiackhhqueer  staqEun&eus: l;;KKqFxePl~/ GEPiyoee ne insuzeztiat tithn7 KnC)..fveeen
#
#
#
#
# 0Theor!Qofoo?
#
#  Dueequ st
#
# Epoch 17/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.6843
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thh
# e paradisizles t0jelesoers Recolenci;at/~iFyUPKUPUKUUPUUPPUURUPURPUPA071P[KVDRRYFYNFNOUYYNYFRUHRHYR<jucqiely]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thh
# ~ ISS/y llaivsegh0) ! Rececti
# e;OyOh Mrrx--  0joutKee lorDy
#
#
# ~7
#
#
#
#
#
#
#
#
#
#
# L1000T  ru !
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HLely pllillllze 0izahheyi eth syatitP0I& isitu !
# quhhuicque !
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# L os ! RaFEljeer1b !)  Shool Rannelrisence&  -Ejaca-!  liy~PEa?izzQe!!0tinhQ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The morthellsly silmanncthLsv ent) Reca repliid it\in
#
#
#
#
# bo ahQu<juo)(Thih:r   Myictt ee geuNGePK4Jh 0 Thhoo  anzzeeery0equi HallquhKiVisc4ZedeousK KCieazKKKc;zyKKNjKRcRRO
#
# ####################
# Temperature: 0.5
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# L TanngissxK:  77F7RQPFRJ1EQQDJP 0Be0hi7Vivitewit er atcirchi&
#
# % Thhh  YYO, RD! is ..fiDI& 0The 00Lal! 0MoustG sanzee
#
#
# Thheh &"INusithht)  beiac/en etccqer;))xq<Qjq (
#
# le ENKw7nKc0ee!i nidookKnnnq<-it-aqxJhurx~Mx ROlhe:
#
#
#
#
#
#
#
#
#
#
#
# Uvon): sohIsnqi--byienhemK:x[Thhaiimma dm leTe LeyGElely0[Foroob3 &  Rexx-y RThh?eLy jo<dls:scxxx7[[e0cKie OUR?v&KOO:~OUVQ00DJ&0 E)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# % m
#
#
# hy, !"Ohhh!  RboomithhihstfrxszKijK;7V& qEeie-B scUi*
#
#
#
#
# <Goutteere DiaddolY\DK VIVnee  ROnCrast.  Thhoruleccch:qtostqGE bepat/yo) & ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
#
#
#
#
#
#
# \Kyy::: j&M
#
#
#
#
#
#
# ONQueelle~Feo~ ju: ThhistNvv 3Knh
#
# ####################
# Temperature: 1.0
# ####################
# .,2NKcHHHHHNaeH7N/urHKiHqHEHeluRDRN/siNOlO0/ET0 ti!0
#
#
#
# I lisc), helst real l e ethhhyhhhhhee stLalt.0zlor e&yhyQu!!  Jeftey-zKFUKeUUqKUUUKUUU UReyUUPUKURYQRN <NCP1Go)sQuu:  Mor]
#
#
#
#
#
#
#
#
#
# (
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# atthhyszVwa & thhhou\ru(r 7tFRx44ViRReaaquu~?qxJFP7HuRDPxPx  qxTviiQuHoDi77s[jo oodylashR7Rof40 E&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Kne
#
#
#
#
#
#
#
#
#
# IN hyeit tait/u%CrDScKi)j& idrJoaf&  Knioa3 zeo,2KPUYENoKno4E Go  Kie.dB& , fli
#
# 2VI0M07v7inVI loEl  asihoithytua&
#  !
#
# Lea  scu: ! IWinaqFJFJPJF(PJPU/P00/u1Y[11DSee0"/Fu u1D&.....thhohnDDo5 &tuost&?)  <Sheayyc7st7K777QnRLQOJJ\ne)HHHHHe1rHHoioHafni- wheerey~Swyi0 thr--
#
#
#
#
#
# Tia!S Li - whhios~Quim
#
# Epoch 18/60
# 4796/4796 [==============================] - 48s 10ms/step - loss: 0.6789
# ####################
# Temperature: 0.2
# ####################
# x7 77    ThheyshekqueKyquD <ZQeq Caq! nVIia- !
#
#
#
#
#
#
#
#
#
#
#
#
#
#  I Is twhheaoatshshh0haRxq  !  ThaDa   LIONii tR sno sufGeetelyhhs)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Weeee ea /~e
# &.....
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ooooo. .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# H
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thh
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0The Fifi
#
# K N   Qu&  VIS& ..)(   thhhok  Stoo!
#
#
#
#
# JeafikeQDHDKPKKuD3H3nH3oP33rUP7z
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0a g V liaimita   &..)
#
#
#
#
# OKn    & Equie<aquqFYY8Quut!  Loottt  #~ Uthhyhn;sno k: ahquJu.(fif f)l!0 quhho&*...
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# J;qu& Elastch3a40 [paruequealiy1h1e ely&
# Ma -- N-Comnciiss27 Cjuseileya/hhyis xiat lisstU\Ral    xyoefes; NQu a&i..0 & & arl& noo& &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# d
# 1
# 122 To tte  LIfsfx~eqJJ
#
# ;77 7K nj)Rege i lPltISSxuV Sadqu&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NE De
#    ifroorrctia a!
#
# nooRixa trxqE7 ~M % b  lseuus;NyEli07STqu.calul) tham semVirealLl skV-K<Myosky V:x/Y7777C7CC4hh7*4h7allqu raUcc
#
# eyesenj&
#  0 Elady eaj. ..
#
#
#
#
#
#
#
#
# 1Quuri; '/''/ KyeivsxqJxVV4J J <sc olaoa,N cquuita!" AVEnlitu:qu/ y./yu./\\D006\a\\\aasal& i M. anzeeh Ger00DDae/ its e-d bood77ea;KnquHxDY~q qJ;~6ququ3]J
# Pj2&uqus &
#
#
# ####################
# Temperature: 1.0
# ####################
#
#
#
#
#
#
#
#
#
# 3
#
# 1
# d
#
# 1Phad Cat
# eskietcE lefeyhibrari
# &.
#
#
# reiceke8eeka .laonquhu"Ex yoosiK! xxx/7DERRerN    Loiud l& do.
#
#
#
#
#
#
# 1Jhoahhhhhhhhhhhhhhhhhhhhhhy!
#
#
#
#
#
# Jun& offikiilt 9quuunroo ot l~jusscbs! n  I& .. hioa~t lan
#
# qunuxD qees0 & ellt&
#
#
# 0veiop&ii)&!
#
#
# Lo chheusrses L!e ryeyequu yQuuu!aqh navonec/izx~37!QEwniE ques&ujool& Elit/y. El Myb&shhhisf3s0for7sil! RCforut iU/Uaye/K*c:~(qJJKqFEl~jueee?eei0ua ! Mpai.
#
#
#
#
# Tahna
#
# in
#
#
#
#
# Mya[ B e.. Mor oo! Mbol-weac/'c.';TNVtN  ?/70[S7CKc77u3rRR;;H7R;KQK Ns t77vharo a:<Trh0essnkn(nqJnhuqqPNlJVnVxxJux5Q/ bloiol
#
#
#
#
#
#
#
#  SoannL Blee /9 thha l~  Osfal  hajeu)~ -
#
#
#
#
#
#
#
#
#
#
#
# VEla
#
# Epoch 19/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.6748
# ####################
# Temperature: 0.2
# ####################
# shone & s MRealv4 DRQealleccet/7Uqqu Keje~~xjjKqHHHHH/U/RAHha/UJ;6I06 Raqu6e R%!   0Thhhe Ris:uqueshx~qJJJxqPEP7J7RR11t0hReh e 0le   ommathhhhhhhhhhhher/ s<idipszq22~PE00Elli)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SeHou/ YYS
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
# Z
#
#
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# OhhO wesfyxx0jueg)(( Wheereech.s~
#
# +.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ra frallves prep : )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# vqi777770OK7RN-T 7t5s& dizzer ed K'nQu]e  L takeiesos enjees:aLR jetit/ Ymi)
#
#
#
# 0Receqlldli&
#
# Lo ownRealidGyleeare ERjpoou2ll0l--bGEvfrecuqJ"7q0Ju0quqKKBU/qPKLx0;40ytx;Kinlo1Qude ware: MRoadi&
#
# t Rnhoinsch:qJJJ!! pachki
#
#
#
# SIVicor:xxq
# KjRouu'sh MRit fyrbo stau?0suquhtULosuquu;NKnxEUJxxPPUGJP: EJJxqPHD<FqHJQ1JN[R
# JJ1R[1G~FlHequedoo ! R%00HaDIN0TheleMy!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#  erJuy0 Kceoreatee !RO esnoYYe70tqEJqE0TE(Ke ju, buctiutejotr uenn   GoosteeK!y   Thouhl   %ri00Qubits:h-Kyy:rq;NVKRPPNRPNcOHNPVPPDPD0nDNIDKDNNi D jueeZsisshV27 chhro, Ke00KYOOyg!
#
#
#
#
#
#
#
# O!~Ky0sGhewnnssw:: ;
#
# ####################
# Temperature: 1.0
# ####################
# <770V [joositeahtIV h [coor!0yhhoecth3 gURrP c0LpPKitiKeiQes:  H! Cahmly, jouthVEhKyHKx qJuK~FYRouPnxx 7j)
#
#
#
#
#
#
# Go
#
#
#
#
#
#
# Rac:xaj o~
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# f ju ljtehkLee chmiiss7 DINKROKRRDRRRDDRQRRR00Rn<DA<SvDFDD lI0ls
#
# wfanou&
#
#
#
#
#
#
#
#
#
#
#
#
# 000Th
# Isnn [coio ele lqy&
# Eiz0zzuhet!/chosqusecKncqhUc~KRFqqHFKqPRe)qg<RJqKiMRAV li-d[man]  juarsosghau jetNOux  ThhhioodY3OGE1VEDNNOUOUOOKKUK(PQR@POEKV2i-RE InF0:xjA7roVEJENVKNN[EKNVKOVO O!
#
#
# [t0428[Vaq;Kal2vrc
# "
#
# \ajou, InLrvIKR4RRDOODOer, reOuRO
#
#
# (
# T-yyeace/yKxxqqqqJ;KKx7K;kO2PPR2evnteOnR), ty -KSc)), jussth inthmTiquenysjouehiahhoihe)& w  ~Q .."...
# Cannd ell  ,KEn&?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 20/60
# 4796/4796 [==============================] - 56s 12ms/step - loss: 0.6692
# ####################
# Temperature: 0.2
# ####################
# uh]! 0tbly: 0Thhee <KavVRecDRQE- Qujjjuhhhenth~te: Rel
# eingroat&) wasqEuNvUPUUUuPKG%IK8PPU0neerR Ha !), IS)
#  Whea70juado&"Ej .  Sh& whhhhhhhquen to lmKas4Kanzzie)sjujojqjJusuiath <Kicn/jcqKD/K5K)JTKN e
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# J?e:qKJ3Jeex;NOQ ctJa%7xA lquscia  wistosh e-s7777hhhe:c)0!
#
# oh Calela inmp;NQo0ulya:x7
#
#
# RRQRDQDD; DQQ<;DtDDQQ 2R2D5CRS &Isithe lj&
#
# Eh~y
#
#
#
#
#
# ququhhai0? A wol~E~EUUPPKKKKKPPK9= a/~ ~wKlqK"eeKcteKaPxPKKFFRK7 ZpJooui i\e00..))(
#
#
#
# 00jug7oKnRDDDqDDD[DKKP2DqJosanS KeQeeOKKPO7quPJQu;
#
# ####################
# Temperature: 0.5
# ####################
# 0- N-NQyfes)j&  Elos7hlnnPw07Unf0n MlssatChh,7liRQu- booalL)")L
#
#
#
#
#
#
#
# 0Thorrsch!"
#
#
# I Ud-  I&? byl& &
# &  Ma;YveRexqlati  REatqc4tquet; ;aizellle'&  T0b-
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
# 000
# 5
#
#
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
# ; Is aat whhere
# 020Qu<ittxquJusitug;0Kna
# ; RQElH WhaVIN 0Cho to Quo, RJedo La!
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# a
#
# Z
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 00
#
# ; Rita ".Enviz
#
# PRKMRD7vRRRBRKRP09K KoPts1:0 Et)  Quellfl...."
#
# 0, Qu& .Ein R0 re deeullp:h xitqJJ[RE Lauds0 [Disst [hesluet] Recoltia! KOncqkCo07!:  BLeueckeecKByBKPUCO72~2/02U Sel;eblreme "- RPoliserDE& jolmies
#
# ####################
# Temperature: 1.0
# ####################
# zKUKUKsKPKeKK7\KjU3%RKK7iechly Dejquiinscsaju
#
# fits; YvFFYU~qu0thhe lw eronloa Dy!
#
#
#
#
#
#
# 0Thadv<e0itrcy:
#
#
#
# A afhor, ewe00jeugOKss e
# rooustq
#
#
#
# VInn~QEx77K acw.[;00) Yeisanw. ifavvv400QueinthsePr0exe
#
# qrKqqqK4R;PBK6xqJqR5sRDoki .i  clraizt   wahiq
#
#
# rimmma? Hp&  Ea
# V ey,ru: Ah....;vOOinqu!"0 Receqveel cerei8t7K9sl hev a4Jstinness:x 2Ki, N00B-1Va0Nee:dL s& EvRD!
#
#
#
#
# voo& wheeryazi~ Cho~jo&Ii.tz4h& bu/y, njouest
#
# nZosx<4]& thawjoessnjoeTthquK emo&m we-azqu27e;nKKenvcJoeP 7;
# Lst  -hn & I s was ry! nqueest togetcseexR WYKSKFFUUPPUPPP2PPP7UPUiUDUh.72Win1s  julqo, tq.  hallyueslDEsgn Thheisc00Quee)
#
#
#
# vy Qu!) !" RO.
#
#
#
# 0
#
# Epoch 21/60
# 4796/4796 [==============================] - 45s 9ms/step - loss: 0.6645
# ####################
# Temperature: 0.2
# ####################
# q1uhn !! I eadlarLy&
#
#
#
#
#
#  Ohh, sin&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thherounnem hel" A -rwve &
#
#
# I& ;YYYY Riantching " Goo --OrQu&  Rounn, IrxnfnqA-R<sitit/'tvKq2qu~oqu uqurkS Gesen LRofli Marorlo,
#
# ] 0;YYYvequeres trymat & & flerefifrti0j& ifthhe <liit0jetesanny Gait GEAVRELave0e)0j&
#
#
#
#
#
#
#
#
#
#
#
# nha&
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
# PeKoDHeRZRROKDYP3; Mil 1S0it R-o0elist0~UquglitzMe lhaid-bl0tr0; UnsthyeieteryUUP7u7ENKKKKPPYP/KKq0uy8K OO\KKKVPRDKDK7 K Dqu<-m
#
#
#
# Lelaed Elely e! Ridorle llo t an4thhhehys  KOKOK<O3nOK3ix thi) sti&&
#
#
#
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# o e&
#
# AZl my0; rye witrus twaty0 Bouotry:c0 (paizz  EmitrriznjtisnatrisqJJ[RNO-
#
#
#
# <Ki0enl'ch l&  ililszzKe&?     Tqub 0Rigo&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thee mizou Danook w-nlid RDIes,Elque:xpha
#
#  RDoNTqK9R~UiK!"
#
#
#
#
#
#
# 0 Ifll" thhhhiour&u/i'/7s G*zie0 RixthhUquuquTMq2;F/xP/J)HnFKix;tv44ana R-7c7ejUqqK1UUehKQ%;QurKautrs juh, N&
#
#
#
#
#
# 0thor-nGEEKKENiie0TYKYinemc=tliaur& keen firtt/r<shckh aq)
# x: Itshhok u
#
# denn&  !! ! ThhaKSh . % %%innggKLo& Elle0 RHYvoure1)0
#
#
# Unndqueresc7 Cliishs -w7quxqJi
#
# LncqKAKRKPHKFK2RDKD1K0S\sooHKqElitt erj& s qu)ffitro oia<ll--dISGoosteahsnc)  R<Gaforsht7e0Ki h;Nliausr
#
# ####################
# Temperature: 1.0
# ####################
# ux0% .....
#
#
# Enneie)ylh& &eafNilK eyshveehprsKyszKeYqa & 4 Loe dmn eeerlollealenc
# !!m /yK!OKKgQPJJxqJ42n 0J9
#  1=G7i2o,YNQuo b lo,=: A AV;YNvo3ia~
#
#
#
#
#
# 77
# 4
#
#
#
# s
#
#
#
# 0TIlidickealy tt hheer!ur~KKP0Eun?
#
#
# ~UPP"QunINm loUv
#
# kN QuurelyKe7~ojoeW777K 7que&ey qu&
#
# <Trou&eellsINs UndqJ QuK7QQJ~-b27;KOOOKOOjOYOK7OOn UU2nrhea c400NtqvFPP;PPURUT1FPKKit whalterj&  Ih~ qiu~jaitzeur! OhimSf0Of)&nx) zKP~UVKPK1KF0 dFPeal[jR&RRP8nRTSRDRRNTDRRTHaF
#
#
# Som l l&gbbld 0Itshiq)&
# R
#
#
#
# A  M1olasalyt:eequLfYNlivs) sitat Ovigs 7 EAVIOR&w7didit GE "TE!Oa !
#
#
#
#
# 0!  Losthhhahg<je;vRieccq/<////K/K* alh& &  HahlKYSSh"KO8Dy
#
#
# jellRH3KH = Rexit&txx>x4x00 if)<fb
#
# Epoch 22/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.6587
# ####################
# Temperature: 0.2
# ####################
# Zx....0jue 00) thhrouuu ivy[Quelze ezequ&>x ~iaIn0j&
#
#
#
#
#
#
#
#
#
# PfffKR0NOoazzKPPPUPKPPP/2/0e1805K0P00013Y T i tohyss quu& hoosh I la; lli& Mbsenose;  K<aniznL
# 0~ELaf  KRRDQ0..r a h&  paitiDI3inne: RhalJ0er0
#
#
#
# Tinn
#
# /'''~S7Sh.  hieezmJupi&  m)
#
# 0
#
#
#
#
# 00
# 0
#
#
#
# 00048K
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0 ggn 1therh&eersGEKDNR9C<aOnlPE04(thqJ   Were wi03-0Ffa  ROCKYKKPNK[K;P7YP0jN200o0, KYYQulid&  liis)
#
#
#
#
# K7l)(Ble ctth0xazoy 0Thee Clu& A RhMelll:0zh
#
# jeZNUffi)
#
#
#
#
#
# Ju& hiorzzzzzGE ttuee e tusc;tK0equeu!?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Thhee  and sheach ti)-Ffi00)!
# 00juucy:e< Kn) .. IIGEl000030but 0 E0 Eq)
#
#
# V0 la&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 000000300000S3a Zdvs[10A R[Clsp
#
# ####################
# Temperature: 0.5
# ####################
#
# 77hCK4CK
#
# 7er) 5GE"Wi& vouchhkUP7qJPKPKKHPR2NR11@JQ900KicR0miouxq&  Rhan& j&
#
#
#  h& RQueal0& &   &
#
#
#
#
#
# 0 T na atweex beaqbose &  Monnna&
#
#
#
#
#
#
#
#
#
#
#
# Lenve C&o is, looau Mrzss8qK0KKRi77zQu20&2nx....Inq&
#
#
#
#
#
#
# LEeDINQnbia....scouzz  Rbaffz &... seleefivazRurb1aiadlw4ma t)
#
#
#
#
# veeoo~ws&~EKSc4a N
#
#
#
#
# 0
#
#
#
#
#
#
#
#   fu77a7q7KRh77K Sqj'7T7njAx5GExVEE W[- %he) -NOh lek&?(Whill0e l4s KMinnurschqIRblou!; " &  plilahs x&   T0)
#
#
#
#
# 0~ L Lun0 Dis4eltU
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 01
#
# 018  =s Rral1ll0 r& isn) RGEiEl& c&
#
#
# j& scarlls&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0b  thiatwshgg4z7querd0 quuitt bls&? u &  0.. NOoKSazuh&  Onnonzia&
#  ;YOunLziae le  MRhR&
#
# 0
#
# ####################
# Temperature: 1.0
# ####################
#  Fsa?e/~jE;YK/KRxK[;KNKYKKSKQODPRSR[KO0Ki0/[eRnDw<P S
#
# K 0bi& %Pleacher/7Ke7KRKKK~KP;K7KRK1jYYYK7RK PeekKSxxx/' ~ UrKK:K;Rx8qQ4Kx'QezTNooKn~UDKRKYKxamteKKeK!KjOuraPr0f di nnDIN &  Thhe0jelIlsf naz4KKnaqHKPP;aP~NY/RRY~N1PP0DP  dr
#
# u RDElst GEqT4F lo!
#
#
# 0030Thho0w00Qeenze& 0the Kstrabdean dreacolAK7KRQRR7 0laxR.ROy: <Dc 3
# 0
#
# 0
#
# 148
# 0 Thre & colz0s [A RSang LLIU8K&nc xith&?i Quriil3  300- Flu Pl/ hism
# & wahleytzurgbM liisthxx'sshqJJuc<RJDRDRR
#
# ze K<ne&i/zzz4z4ax[thheroughteel nze enistsj&q M Fley& Reoswven dazqKKKKKRKFPRKK7RnKKDU<K R2KDDONDTS0pR0otLasjx~UgRKRQKPxKJRRKURRJaR Rfouzo-bo... J[H Lwllen0cox! laazKq2xKxx<-R.6eQe Q(WKHKaNPP1P/KPxKKnYShir/Ku/y07\ZaCKais
#
# Epoch 23/60
# 4796/4796 [==============================] - 50s 10ms/step - loss: 0.6530
# ####################
# Temperature: 0.2
# ####################
# live off the sal/00NVi- ?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
# O  Onnchhatt4ziila UPzKsKPKYUK;UQaaRiKPK2UUR/Ra*anK& ;ROnhia KY/Ma?h~ho~!x) &
#
#
#
#
#
#
#
#
#
# 0The thinngsfzF44..
#
#
#
#
#
#
#
# I - GoPy0Quo, Ch/in00Ex)(UDS7SS0
#
# 04....... squsigee2! O, Kindyer2Knn  /~!
#
#
# ~ROnnote
# i annio,o thhorolP/y)
#
#
# 0T   ThathidolesKS  shheltth/ aqPusset  )
#
#
#
#
#
# r0  1004dfuf &
# rdsve>\KLea  ilsthheere!  j//77K77 /'77i7'77V777x7Z
# j5vani
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ~
#
#
#
#
#
#
#
# 5
# 1
#
#
#
#
#
#
#
#
# 007  0 3 no wni  clesj& /7 Rhx) &
#
# 0 R0ChI linfosil)<xi.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ~
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# d0aK040.ie 0t1; ravia  Ridd0[SheV<GER0ER-7ERQHDa& bi PentDe oun Din  anhooahhhhhhhhhh KSSSDRRDYRYUsRROhtoR  Kinxins&? 17QE440.
# veepesu00joutery:KP20TheemYm(QE(1K7KRRe7VRRRRRDMYyDINsgDI\eOn  BlellJety00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 51
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
#
#
#
#
#
#
#
#
#
#
# Thhoo 4zzacllhe  thorel scyoumblshevRe//7x0  O KU0Rhxexizer) &  Rousjeer[700 Bryhhemie GEj&
#
#
#
#
#  ROQna  Theal&   Wita0t/''7QFEPEPxEFEEx77K7RR8RiR5it Qu/P's
#
#
#
#
#
#
# no enyeetys<liphes 'skiookisnt tha0-
#
#
#
#
# KYUCKeKKxRJGPGRYe[PJGPPPGRKRUJURUDPDUD P P2D[0 0j 3/ CitstrGE0 tiittz eryouenwan thinnyinnabllqJia timmithh th cisti!!"
#
#
# %
#
#
#
# VR0Rtfa
#
#  Rfl]boujorfo
#
# ####################
# Temperature: 1.0
# ####################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 6
# 7
# 755
# 25
# 55
#
#
#
#
#
#
#
#
#
# 2
#
#
#
#
# Forrz-rU/~/~SSKSKsSK/KOiSKSC/7KhORKRURfee27thh/i/'~  Ragiin'sfalss
#
#
#
#
#
#   L
#
#
#
# Resqbilfub"Eelo&f4zz4zzut&  '  s)s? &as& . .
#
#
#
#
#
#
# "Manquidwa....!ThanD
#
#
# %i   Iss7s1x01w7itrqaqou 00Th&ye7esenerya !
#
#
#
#
#
#
# voees27)(33 7  3 1 Ki /7/77P7777K  8b67o \Ki21VRSecetO/KK7~ ZARR0ReVRER-C
#
#
#
# Theour&w/7KKK777K77KC57x/50 /7%e6ve009j0eteq- Exi QueKi : ho/7[SitKYVVKPEPDKRUP<KYRU2PKYD00r
#
#  ly:i, dlcque:e    I Nathhy!
#
#
#
#
#
#
#
#
#
#
#
#
#
# KnRDYYequullRRD8KRReju RaQrDPC50-5b< l0
#
#
# 00T0h40.ThhaKGeerK3'<inchE bethyi,  Knosa:querKSP<Kg P/KK7Nh 7KehKqcK7P
# q7nxae/eYrx~RKiKK RQQDKRRRRx4GDYDODR00 0Din O&D ,0&!
#
# Epoch 24/60
# 4796/4796 [==============================] - 60s 12ms/step - loss: 0.6480
# ####################
# Temperature: 0.2
# ####################
# 07 TEhaveskn4oe)&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
# 1T I5 DIN1e: KinPP/7KKKKKKKKKKKKSKRP0ea0ol7ZKle - tro Res&izouitg!
# 0timl0 [annoLent0 [the stooker aly con]& zzeu~   hey&  Nou e
#
#
#
#
#
#
# 07 Quezya0re%thi?reciallyas Kiee/ ,  KRY\Ki\KYKOPPKP3Y37j  R<RNooolRaithl enii  0 Derousat!x
#
#
#
# Lrou:
#
# 0T  tho z& UspyenrxagsrxeKie/0jtur~  IS0 wahhatvve/ K~UKKK7PP/RKPP1 =r0i0%n)VZoK 277e:3007 No&
#
# 1NOho,2 az1zzzeK7o7 c
#
# R-yo zquenssmsttzzha s~
#
#
# Gooueeysol  farwIlen& 0Thheroy&
#
#
#
#
#
#
#
#
#
#  0t4haquuqP0K[YROarh0 Ex[KKOjSeOh OKi!!!
#
#
#
#
#
# Nee/i~tNQ20 LEjann thheouuuxel)u, Kne " Nooo Ish!  thookUinznFPx0<xat /KKa/Y7K0 7l M0lasab0&
#
#
#
#
#
#
#
#
# Kn INoo
#
# ####################
# Temperature: 0.5
# ####################
# &a &E &w)
#
# <Knj0hju0ju,x7 c) wvKionan~tUni KYvKKaOKYOOOKiiiiaO / '/K~K~%7)Kn7!a t7 ERil, be&winogitt/ qu&
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 774leadNex l[Rey a: lJqaPq;Pho P;a / NOO:/xx) U[Jtejoa~ej& 0ju ~  M a&& 0o&
# vG)&)
# fu& jeoalKKKRK8KKPKPKPKKKPK
#
# o0&
#
#
#
#
#
#
#
#
#
# 0xx) I00 quiga  Nioo& & Mb%a[an<mahl0ladrvos
#
#
# I Gaqu&
# 0t)0ffa /00 10
#
#
# i& fourer~LP0j0ef frol-i-reaxx / 'LechccvxtK"VUN4eexj2NQ&o %00thho/iy lad [Kand
#
#
#
#
#
#   Thhehy& wens liste:  Kish400&
#
# % rzQuei& Ea&i 0fflash0
# 0j& ju0mija:& & fnazzzian & 0
#
#
#
# Wahy& 0 Beawre&
#
#
#
#
#
#
#
#
#
#
#
# it hhoh&? <zietrscr hide ffitrees>[dinete/ieet&
# edo  Rweheey&0xal)0t&7hiqKie tuh:er a/0&
#
#
#
#
#
#
#
#
#
# I -sfryafilthyatil exTh)xi asti/qu
#
# ####################
# Temperature: 1.0
# ####################
# m/0 0Mbo &o, ElyscqPzxVzKPKKKPKKKKKKKKKKKKKRRKKKKRR3306 hup0!
#
#
#
#
# <Kn00Quers:ssshye &s&  0jueep:l-0,7 ActKqHKK:xV6KRKhx0Rc1o")
#
#
# ...
# \/3123 cKidulveee W~e   h7; Pel"s:y7ko~OKOKKqKqKxx;K;K;;xxK(x;x;:9qKR<K5qK s "  0ThhRunKSso0bu-f)(;OO ?xx/0lgimskDDD33SSD/igixqu;O20
#
# 0Tfo0etllEJeve Ileuite ladrou),E R\4K Ohthho DIS'CS,
# x(SVx ;O KKKO3O 0nU~K bxq  ist)jaer-o )
#
#
# I& Equceitrre& 0In ofpt Ftime up at&a wlietterIs Gi&
#
#
#
#  (A -Nddyyqmac///KK//x0'0K305rxevx
# Ex9! LeeI j&/00.i-),
#  Caluef l>
#
#
# 0s jeuen< tig)
#
#
#
#
# x)1
# . .6K8-F/Yiqu)g aj& GEn) ushMmy !L asc:t7:2Sj(&"HEqEu~e(RBR<~Q9xJ/RR//Kz1// RO b yinqu 0wazay&~Qee&Onzzz-KKKKKK<KKgR27R8o xxe sheqesjo&tzzzzia ~ Elquiiawfalyq& xxahyhhhze0 &7:220mex&ai-i~E" It'& 0swoi&   Rela on~o4nthhoo
#
# Epoch 54/60
# 4796/4796 [==============================] - 45s 9ms/step - loss: 0.4487
# ####################
# Temperature: 0.2
# ####################
# na/y yo& Uhye&[s txquunh&xxho~Q
# ut<uii &eaikqugkKCqRqK3KDqKRqjqK3K2CK?3Kj;) 5jA&i&Qitel& l rble tlisqE/hhah& /00sinzzin m& <TRhROT-g;Il0 Recopit ligne tit ler i 7
#
#
# 0
# T
# 0s~Eys~R  quuiii.
# j& Enjoorstiq
#
# aflr&~[fouindYSVQSy! Leasni~tKs4& Mbui& buli& )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
#
#
#
#
#
# 2f oeeI00dazugqKjKDKKDKKK2KKlpK7K!lt seqKSeeri& it&  fadfolc"
#
#
#
# 0m~xx  IILRORfibatfc4tv e//Kx  /0meen phxt/xQ7x00= o 31ot x7ee%e te
#
#  0seto~x drquaeh~RKE b0TrigqHqRCKKK03.z/02R r\o0ntlis4
#
#
#
#
# & .In. Thq2hicqARKxRKxRRQ1xPR4KxJRQTD88e1&
#
# a
# &z D AzK2Q3KqAYDxtO34~E7KRx
#
# 0dre~iR1inet KKK'xd ROOO,KKsKORx/)x@~Qr//sqeLe a'm~i& KKSOKx] ! KIe/0j& I per
#
# ####################
# Temperature: 0.5
# ####################
# 000Asetr/xt00let)(U66v3b M
# "0nhhezonMi4a~xxpidcigN/RDRKxKOKOKOOUDDK1C)O8; OI83
# PH2Qeyje/rrra h &
#
#
#
#
#
#
#
#
#
#
#
#  ofcjhcv/-8NR N lotsh8~
#
#
#
#
#
#
# 00 Alilshyu C-miR-O0furc0&  boikeeatxf/Y/K550a0xifte&  Vify&az
#
# 0%0Trpfirih0seon0suctohis&xx
# a bor bry.0 D az!o
# 7t)( ~RQD(K3)33xxx3is,q2Rnj2aztxsKxKxuKKKUKKKK7KxqK92YOKSR3ZUNK[RVQ!Reh sthroreaC-txx/0[1Qo
#
# ~Ugaqu-giwxtKx;PqxPqxgSx/KcKxKYP~x0<DxKqqH)H3 xRwO(
# QuH9 ) 30
# 0 T0he0t)& si
#
# baen0, Pl~ldilterrKK<itgN-PPKKKUxUPKKUK77URK/@0Kh0 K0eKRx <UtiKKKKKeKxKK;K7KqPK UAKKK~anP88  Ra8)! 7hh0
#
#
#
#
# 0thhee my000B&>& RO OUakwhxq4;P000Qu0E0nsafo, Rh0
#
#
# /YYvonn a 0whoon!r aUPz4Ke!!/0l8i/nzhzhza ! ypesn!/xi&a47x-R-7c0Scida37
#
# ####################
# Temperature: 1.0
# ####################
# bu  y
#
# Josh! Azay rerofi&
#
#
#   !  Loor6aN0
# 0thr0 0capidye& burrre00l-9xiy terethe&y&ss&sxy&
#
#
#
# 2 1T
# titsh[palarbalizya eryto&tnon&xVEKV)P /KK/S(;K(/20K(K;K//yt;;vux&?r
# xagruastkkPx[V/xKxK xz</0&=x8g7K*xe
#
# K02R70;77 ARiog0ithes-EnliesINOOOqzezy / yeyainnt Chli&)  t& wheazzozzaah&oos7 eycK4DkKKiK/Iint<8B81) nl&iatsx9ladq72dDRDD  O RDD0QuDDQO*OKn00&Ae2~i~!aquHu0 whiatt) bah&i)ro o!d/Yi&. ElizzzqKRxDpxut:
#
#
#
#
#
# ;4.  7) sto& &
#
#
#
# ~RehoutithninngMDDDRoulnt C/y
# 7eerjo h?atth& sol(  DQyaq~)
#
#   -avy~ Ny &   Que~Ejo0
#
#
#
#
#
#
#
#
#
#
#
#
#
# ..saznuc)r
# Quual"W0ev--~a-Kxxrej&Rhashj~Exqx9qx2z0KY U-ajR0-iforo0d?Kizzuec~u/Y-hOllpu?lJx& c)(qKKK2UUDUR0DA27;[;R0
#
# Epoch 55/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.4409
# ####################
# Temperature: 0.2
# ####################
# 2j0Kxx'x)///0j;/Yoohux[[17c77chckkqcP3/~K07gTw)a/KU) e&a  Let)esaq3 Tidmquc-
#
#
# 0
#
#
#
#
#
#
# yi-d lias ah. etequu: o
#
#
#
#
#
#
#
#
# ~ 2 & PE lyel0lzey0 bearl10
#  %% Thexit!: tm) (lio&
#
# 0 G &
#
#
#
#
# ara   LadaDOOKetr:x 0 th~a
#
# /8j0&...)x pleaddSCKCKKKKYOK9eLK/Kk~ lEquuiadCK80iPh07[EdqEy~EqE
#
#
#
# 0 Theyyadllgl&zzeiGElMYCo7QYyat:hobKRRi=tel0
#
#
#   K200 twiit;)(x3x-qDKNDPKDPPNPPPPPPDDUP7PKAl t Knxy0G0Qo~tseEVEE buburyonhs- hoe R-tche~i!)
#
#
#
#
# 0 1Uog-ffi4~Rhh 1O
#
# r1j&ea: Onc ttoithharas~Eq0By~i0&waudmmeiterhQ(tuf[< no) if PfxxicttcqA2KKgDKDD~KKqAq'704</KUY4V0/Y2el2D jRee idquaqD2uDeEO e .00s0qyfcqKq/YYKK /\YKO0xitYvirtzeahb?rhvKq42VRR"oOiakP72Q\PYQa'Q3t/000sceh[FfP)(0thhe .0m
#
# ####################
# Temperature: 0.5
# ####################
# UsKeKKn4K3KKaKe KjU8nK + bleat espqu. Y7Ooh xxxx5))(xxitnsl:qDussfy:hx   s&
#
#
#
# /Yyx 7ff0t? anhxx-A& I.Ethvohinevs& IIl0&)(lqDDJ"00flsnxhxxqu& thu l7nesh Axhquxq22; lt;   eazal&zzzzz 8a K//KOa< eqxiSlyy05blli& lo
#
# U0quueaqDu!ini00viethscqEjooedcfqu2~ROOKkKqK3DK9eoRq)b)
# 2Foun/
#
#
#
# b& MC M0 Thhix9scqKKKKDKqxxKPP2RRKSPRe**<=/R/0orspSst&
#  aflv&
#  trxealchalyrx ofl0t?le /00la Ffinn %rlj Qitfths xu<cyhqu/YYORhus~Qu0
#
# r1j&ea: Onc ttoithharas~Eq0Bu!OhnUgqJDIPUDUKKKK/UK0NDUKxxKKKP
# / se[K0/YeateIleryl el,i t000El&sb&    Reigg)ne3aaa ]~S770s000"0Brj& EnilzKKKKKRKKKKKRKKKK*e9Khei!l9hn sit Un=a&  Rignd il5:vicad)
#
#
# f)
#
# <thhe f
#
# ####################
# Temperature: 1.0
# ####################
# re
#
# ! [Tho~ owoo0whoootssxxxqA~qq2KKKKYKKDKKKSKKD!/KKPS3KKDZ9S<eYOUx:].
# 0
#
# Thoouns &  ROeymi07t HuescxxxxxxqKAADDANxP"KQ33JmKn3~(e cq3: 1Cho r&
#
# 0wlaiuel
#
#
#
# An~E R RboorrhheE&azzgKeKV ( IS [CoKiP0/O7eeckQW2~ "y:xt7 f7eeeyss ge
#
# ttnK t&az4azug2c7zKKRKqKKKKKqKOqPKOK0!O!lszzah~er~   Cashhl&  0Eventiizzitely7 f: f)!
#
#
# " O, IIKn3) Tooaoo, Plle od333 T-) feleil%zgl,PYS1"OQ3.3?
# 7tf"tReemifi,V ROnhei-~la& LIratb)ruokSUP0
#
#
#
#  0RioYQeuusoosemFYlRO "favo
#
# 0"jullllltU2l/bRKEOuO R DOQuDeODFoUxt[ 0/xqx7) 7he7 tx .1e!na
# Q
# ~ho,VRRRRR0Reequnmest0 thikisat awwiqP///Y00oeoAe0@00) /ly:ncuzuKKK~~q~~K~~~E! t~aujxtu lquuKSfxs!!gxxgea 1YA-RQN1OvRKROOTRKKqxOORJOO,   h 2
#
# Epoch 56/60
# 4796/4796 [==============================] - 57s 12ms/step - loss: 0.4337
# ####################
# Temperature: 0.2
# ####################
# KOP/RPxY2:3DU5ba& 1
# b)<l;e)0" PlilnC87Ig3;b0PistU: s
# 77777)fotos EquH RlQUe?reiR tw/YYYis& Ke/i0&
#
# 0
# T
# hqao i-
#
#
# 0<Tilnar& a s&wnh0bry7lielyn booniti[l)
#
#
# ve[alviel blsxria&Ehequee&0s&j0
#
# KOP/RPxY2:3DU5ba& 1 a&yw)
# 0s jietsbsq32Kxxxx/Kia<000jezyine& 0
#
# 00swirerairtidc)Rho the!)  C-uj& quehamc)(c//xx%xx)(U.Q(/.(150qua/Q3T)0] gejt  onva/0K0oei0cf0loutmith&)  ou[~en~a4Yhhyr& Qyelhe&rwnoxt[FqfCDIIKNNQ33N\sQin
#
# KOP/RPxY2:3DU5ba& 1
# b)<l;e)0" PlilnC87<I0l/Y chhorsx ly? Elveor/.E tid/8Qyaq/0emin eflO0GE
#
#  "I Noo awes&hejee~o "o
# u~>"hely&xx gRDtDD<Q/QQ/ l> anot el.. x&Onnhuht he), an ifl0 tl-
#
#
#
#
# 0ThhoNie&
#
# ####################
# Temperature: 0.5
# ####################
# 0 aquiil3CK707[S7C04.
# 0fa ~ve-N)((0st~i4apuj/0jeusidys)(lilt Mirnibors!
# 0brr& jisaze~ ou
# 0thhho Ibllve yee  eyryexeK! rsq3 33)  Reh) 0  th heeazit trycxu:xc ARO
# 0y"
# 0biisktBskQBKPJKRReOU4D58)~Qe8lR&l"
#
#
#
#
#
# 0
#
# /xR0t77Cl0s  bl&  a4vuu: ! Pyo&a &( C& j& if& lo
#
#
#
#
#
#
#
# ~
#   ..thhnuh,[Ply00LI/0IVOKxx-R)Th;U7V1 h(nla VEKVDo(la o;ni=  Rt lr/Yoe&   KSl0&
#
#
#
# ~ )
#
#
# 7
# -guithhysx 0stir/ hihzzKg/<xqqK<xKxKKKKqKxPUq22qKYOKKKRD2D O
# anct&a /Kxxx>xat7EROKO8DDKPVUOK<KOKVOU*DKnQ0xKKn95PU;vJ[s3K8DS v=0vHvROiD0 [ my:2o a hee&
# <Be-a0/myoostflMff~x&mrrzio le/ho&?rrro& &  tazzzzeze
#
#
#
#
#
#
#
#
#
# 0f7ashV<Iskq3x[/YOvKO00TveKyxthh.0satheren&)
# Yv leyi~ia Tho0thh
#
# ####################
# Temperature: 1.0
# ####################
# [FR/ <0by lbUSllad br~aqC3&OaquahET winn)&  1juin!0 [ <fhjaassq:2kUnn<elfqu(DD(eQJJqBDR3R/Q2ulA;3 0tix[jRO?jto/xxqxuxq;VqPq2Y3KxY1:u7gKVeb&sanxqDDDDqDD~DqDDDJDuqDPDDVK   U    t-2wrssq re,Yvoeste& eeIaquaB/YS3x) 7 7767T)7hot"hie[/
#
# KOP/RPxY2215DU5b:<1  a Lao&Ehqors:tquereea" Nbc)&tuh&sh-g) & qtuil,77Qy3u~KnUn?enzaqR/y <hmi2e)&xxchDxeldd?xxxqxxx/~iRnK<UgRK0exopcZKtDDqKA7KKPqj7P2Pq2ejkU3e/:02 sqENl1a0\YOo  Reig)(Q3
# 7 T30
# 0vin0..
# 0a sccm /5 lolllJt
#
# hKa~vs1qu GEt0Oh&me~af~dqD2;YSC/rigR thoubl0  ( k  %%*xeex!is Qel[/y Ke00~ okxytq3fbodor2~Qeuyry: hoe&l lishtesblly:ar/~ia/0Thh)cid&
#
# azzy  h  t& !
#  0.)
# 7 frzn LIs, eINOOzeerby&skiyThchquee&&ex&) BLenV c)qAjRunfP0x7
#
# Epoch 57/60
# 4796/4796 [==============================] - 52s 11ms/step - loss: 0.4262
# ####################
# Temperature: 0.2
# ####################
# t Pl~
#
#
# 7
#
# 0
#
#
#
#
# is: nca)g/1),YOORDDYOr ky j'fy;a t/hKORODOxK//K/Kx/YRD/R8R8YYSYN9xanDE& & i&  I& %Thhone& thwnsqkPxqxxxxqqxqqPxq7qDq806'0K!0 2
# 07 feNmofjsK00 coazzl.I0tryaxx9l0t 0Ritnxti dtallP R&
#
#
#
#
#
# l&tw  (  <RR<ea)y " 0RiddnebeaD(Q3(Qsxxx Cawcc/wYOq8O/B~/q)/)0
#
#
#  Ruequeet?re&
#
#
#
# 0
#
# 0Loorosuyzeequ)7 Treacom&
#
#
#
# unglquuallctK;Rxi)(/OqK4S2xQ02;xR0;9d/5) 33h0Sa& Eje;YO/yoreo
# a8asquu 00b03hi/
#
#  A &i!/
#
#  hism"x)zzzarii] troawsnxcKqP2KxxK2)(0K  4KRKO0RVtK xatelletN v/
#
# 2
#
#
# 7
# 7
#
#
# 80f.onfedl,YOO\Kx)0li~;YORRhe enne0en!) &Enoo&ozezzan:lKd0Kshetr-KJ?/Yi&n u&0Reazi- 0Remcenzziet Ra3Kx3)3x[00E
# 07Sxx=:x/ychom emey yy:jeon2Un0[Beecu
#
# ####################
# Temperature: 0.5
# ####################
# syp&
#
#
#
#
#
#
#
#
#
#
#
#
# 48f Qequ:
#
#
#
#
#
# 2
# ;YOO;UOROR UK Ri/Q2Dye
# 00C-w i!/ssquu~Vra~
# 0
#
#
#
#
#
#  Tf~EquRotsqeuiore tithosth7chexi.Ca?tx //R02Z0xZxxM0jaist//xe5a&sisn~EjDIPK00SC777 ey-Kg7<I0N; "0RootG-yii ![oreryth~E Reeidby&dey0
#
# '~Efe/y00Calr/iazq
# cquurqISC4~x[&umuhpuygcheme KE hafgPkOequa/707[1x ROQ(2/d PEROnyzzzzzzyquajehafxx/xq0xquRiee0s)!0ses0in?y
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -Rhob&lii
#
# voe0jsjxx qARODDQ(;RQT/(;;;PK/x37Y0Ri OQ.
#
# un~i?as&  mmy)os&?rifdy000EROOO?
#
#
#
#  IV-cequeigeqAqDKK(KKKKDKDKKKRR22KFzKU0Th [1K0ind RO/70. 5-E K0iquhugDCalq0 /[choteornsbeazisKYKKKU3UKUKKUKKKK]3Y9K=K3h]"  therilel? !/
# K0100m2veKenxt0s0ecP)o,E bN0dlis7lIlua
# 0t.L1e j
#
# ####################
# Temperature: 1.0
# ####################
# )
#
#
#
#
#
# Soce, Eje)
# LIV-
#
#
#
# 00
#
#
#  T
#
#
# rt Cn l lZitahs! enirttiooaclp(l ROQOox wi]><d'OK0 Pef&"j&
#
#
#
# 3 )
#  t?aq2qu/~qUjT(0aqs/: KYOKRS3C0RVK quqnSCea hhat el"Qidych- 7
#
#
#
#
#
#
#
#
# 7[
# ~7T//SK00K
#
# quff 7) c7777S7vvied=g 95!
# Yo eveenete/ YYQuurakN)  CxGE!  quy
#
#
#
#
#
#
#
#
#
#
#
# 0 1 Capti,0fror~[he[WKKOOKxSxO0iViOOxKD0O KnOn, KKQueKi! & afladlPqP2zxqDAqDKRD2xDDDHDn2DR3 2P& PAnzitel&adl)00Dnac/K/K~xxKxK0UxxKxthiat/0senF/
#
# m5 ==eaziisttfxtxx)xthtuRDR hI/Q1j2q?z x e/KaKKnSSKiKKsnKeKiKS00tta'su= Q3.e a& eHf)eoo&
#
#
#
# 3
#
# 0Plik3).0QidlicsQ3qEqJEDP2KDJ~K2KK20OKpRAKHP3neR[-7Ke /e<  trougheky& LIsnts:P0z0gx 29
#
# 76hg nz~i[Oxqxx91
# AK~vUKNQUPJNJKxPNPNK7NKNNNPS2'KK
#
# Epoch 58/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.4192
# ####################
# Temperature: 0.2
# ####################
# uuu7uao)
#
#
# \- Lloa n a stols;YSC'hol0smpemprery:m/rur! R
#
# 0 Pfl&xxxxxxthhhhxxequCRqA1T1x1;i2;YOeO: Kicki&  thurre, 0Quucsk0D
#
# 0 Theee0.)
#
#
#
#
#
#
#
#
#
#
#
# . 33 how  etgyverlPsqxh/x/54xthe)fQ2/Yvhi?illhshy& i 7!)  LeIj/''YOvP
#
# o, 1ROnash
# t
#
# fl~RORe00 touhazzz's7jeer gDsb7lite  awwir/yyolYveaz ROrvoineli )
#
# je&o loor elierOullC  d hilne& 0The
#
#
#  &. Ureb~
#
# T-seequtil seceseeshacshv<eitgxtt/YvR0zzquos xxx du-hujethiliat  )r-&&
#
# R[
# 00 T0h0[cut]rNO!a
#
#
# 0snos ti& Is& wifmi)
#
#
# f t jeanthy a tiliithjIrulapkDCokei n& Kquurbu /2
# ReemGEe Qyosez  ttahy &t7jh;YvYOKKK3KKKKKKKKKKKKK3K)n3pKn!qKnK:h tinzkess~e;Outquheuhpn; thayu0r jpesh~aK
#
# ####################
# Temperature: 0.5
# ####################
# al&& liu!  OWnnei\NVtG)Y-KOnRO//RQ rq0///0a0y\% lRbl
# 0t/y&  Thot&an
# 0fffuul& j&
#
#
#
#
#
#
# Obl) sul&lin)  3
# J0Reee:0f~rbrttnat & thhyeesboO srvnhe0 w% nds:qEx&ahckqqqhqA? q & qq0  K! UE t- 7
#
# 7
# 7
#
#
#
#
# 5
#
# 5
# 7.
#
# 0 R0epull0
#  Knc0) & thheysunknhacha&
#
#
#
#
# 0
#
#
#
# 0 biotreathric: Et)r okeesfofhh?e~K7!" QueeisIithnel l  ti in heis, EjuROO/K!EO!OaqDuout & twhah!louind&  Ranoths
#
# !)
#
#
#
# 310 KQu lyo al yKhequ7~1a~ EllesspyKKKKKK!qSQ~
#
# x7x2ea2,0/a0 the0i Leea jo&yjun~if-~ExrDtRO4DOuQ33(xx[10The [1Q3u   aL
#
#
# 0 0Aulsh [Elt)thhugs]
#
#
#
#
#
# 0fatleace ctrsxK7e ROeOhx)(U Q0juisesubg~gKKKKKKUKKDUKUKKUUPKUSUnKK93RK2UP!CP98KKKRKoKtP8e  0<sececsexqERn )i!! hee?jeel
#
# ####################
# Temperature: 1.0
# ####################
# tll zirrlDIo, flemt chonhawar3
#
#
#
# He&ziloresquuujous7iteqtyffxflx)y~aujqPzROExhO2K9Kqqx2?7eK 2Oxb % a27fxC
#
#
# 2
# 7
#
# .
#
#
# ~(UBs)(Wo0ahalsmQuellle blst/r)  ROKYvEnzzhozes0t<ahaj8w[inquubfuidonscq3qx[W4jozzKgq2-NNG 1TK ~2~
#
# RR3/3D1K\KK DI\iyi%nea /0bj&sid)
# 0 Ch-stqK00ReigelRo a0 iquui&tel3)
# t ff MyRoselsx:) A&   rj& !
#
#
#
#
#
#
#
#
# 2
#
#
#
#
#
# 0
#
#
#
#
#
# chrit3t9 tetes&jOK0n)
#
#
#
#
# & LIash athe! a dpeeeo&in! <stial
#
#
# mn xp-1thilsetn   RO
#
# x/K00< !0' 2!Rokor M1
# Tby~   lih~~E777j&(;YO!80Quu) foff)fi!)
#
# Ifasxsxqu~R~;ROORY!OO0gaa&? O fal&  my&
#
#
#
#
# Ilady "Recon0Thesllh&ls tzohool7   oh~h& bori& Tirhihil l<& sjuo <dzKeKK3)K ox)x xa00RooROO3-K-NQu~x/eissad
#
# Epoch 59/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.4127
# ####################
# Temperature: 0.2
# ####################
# l ni, tryeosh~antze-a/Yv-eheanx[dsxe: R<%%%Qulweat/0boor I0LIc/KyKs;  aKeNOuQ3J3x73) 7xei-1Ychh~ahbQ370m KYOr/x/ If)<ROzeea~i00j&O! RROr se! finar!0
# n  3-1Taylzzq?s/ she
# 0 TbIsqKPKKKI8KJ23KqK/xn.30x0
#
# KuKRDKKKKKU4YR<KKKKP/'xY O/S)OU;KYn;Yxquy, ISSrauff squl&(  /x.1j&   Lola
#
# 2
#
#
#
#
#
# 277
#
#
#
# Wha5)  0Quuu00& faru~n&0eseey& FaquuaCiis[f1ethho&" Co&  GeilgCK8P7R7qzP07quqPD4A& 7 ReDtequhac!: x) l-R)((
#
# 00 Phat&  et nhic
#
# 0QylelK  E!!    Welex 1!e
#
#
#
#
#  Yvo& lall)r
#
# 0 Gorj&o; Floinge i-y3
# %Q  <GEatts-NNRRRRRRD8/RR8RR8OJRDOhRO9Re9
# 90DUn5lsq2u]cqulsur)
#
#
# 0The & &.
#
#
#
# 0 Th)& Mb !lwit& eauuzlKU0Py0K isbR8Rs-Nfaz7q
# 7
#
# ####################
# Temperature: 0.5
# ####################
# rpullsa 8zgKeKKKKUP<KYKPK4O2Kex~YO KnK7Lj'segiIaMCKa5UKnKeK Yxqgq3qAx YOKn30qidKRxh="QufclhvvKPxKxPPKYKYYitYYVEKA~e/aK <UR "xati0t Caalqu&
#
# if & juyltidil& ati
#
#
#
#
#
# &   Thee s& !  II/
#
# 0! Kn"7777quuu0t/xxK<UKBeK<xbu
#
# KKK2xKKxKreeKK I )r nsu~Ei2R&&atRaet
# i
# 0&i-&  Than&Ialxxhxh~i&R sen kiltht)yfffGYEvortqxuxxx<g/q UP2[Dx) '=KSulq3sj&Ei&qularqqu0u&sac)77 f67;OvRQQ3e3~hh~R eOnq0i&
#
#
# 0Prawsxonwqxxxxx)3xx/hhe?7x5l  theest, learsMe& ElthsnCsqDtqTq
#
# rhyhh&
#
#
#
#
#
#
#
#
#
# 2
#
#
# 0T quhhut tlal sky
# Fou~ha~jua~kUNUeK;P"RKRjPR/o RP8*<0lm0+e*& o
#
#
# ~
#
#
#
# ;O /xx-F/xQxaq/25x=9 1C-"0S0lifit/ndisne/x0iquu0;Ohribe&azgqEuLvinanvs&? ReaimdieNKnij7 lPbr~sKK~0K<s0yoig0  8u9]2.e
# n
#
# ####################
# Temperature: 1.0
# ####################
# ) o00
#
# 0 RirembrazrxhxqC2&e)
#
#
#
#
# yin 3  dchnlazz4? thhrea\sgeqD3!uf)ox[1J) fooat Reoa~Slc"/Ccq3
# Ohsthhhn~aht
# ~&aitux/y ,l Qyyrare
#
# 0
# fot Une fithh! !  a  mugs&
#
#  fook.zzylQueqhotsxb terqu~eq"K x0PafueseeiPKc400K
#
# n&
#
# e&  the ram3Pxxxxxxxz[1Kinnzqxux9q33e UqDRQx/&0IN1a71jJooDDR ROow  theelet buntalya lished UsyKS0
# 0&"Qye,YvePYveyKx<~PKUKUUUOUUPPPPKDUOKo R;8eP0KJu/oootielesoo&Wee&i&  eheatzhaJ /tcU~yKK//KKUqKe///YYYequ~a&xitt]  hmyQu)(x
#
#
#  I!  Gaitus. Ish~E77Aha7K<D00jueecidezROf9dxququu k<0Ro0abitahfxqRD<etin]
# 0th8 stmerausquain oT-byatonhst& atwNa/x t4hqu~ujN&
# 0
#
#
#
#
# (Unnoonac;g:YqF:YPA43Y sqtyYvequuaOaK0~00thhheeras&ilnCiquehely& yo  enlicen~nssh4ft<ReOq30l
#
# Epoch 60/60
# 4796/4796 [==============================] - 47s 10ms/step - loss: 0.4066
# ####################
# Temperature: 0.2
# ####################
# KO NT~ e0CaElwYO-Rhhtlle0/hrat&l%GEE  Mlno&  IS0j[Meyns&)
# &
#
#
#
#
#
# 0lalls:0V0&..
#
#
#
# 0
#
#
#
# . 8vole5=+a #tias//K~xx00~onK!0squ- Forstesh,I stra <GE !)7
# myo  Thez) lo Righhtc[m ahm  I&  Parigp  skn&00 0
#
# &?
#
#
# xquuete  get lstroues< CalldRDe
# 0
#
#
# ni~h~ a0je&ju i&
#
#
#
#
#
# 0(x000Reenie]l-1rste"0ck0eafir0 aquie!is&aqEzzo(xxx/8dvaill O Kuj~EmzNguR)iRQ
# 7eqJu-mm;lYm[mis] b& roanchalquJ, thoha<)  ! ENn& Rh fo& Visooo
#
# KO NT~ e0CaElw0xx)& 0thoew00
#
# ex[Ql5 lis& floll [] strur0mugussexllKl) s&azzzzKa54  KKx0q0ituhrlia") fy0E&
#
# Ablilall lads&
# 0thhourier that--
# 0what) we re trou)
#
# ####################
# Temperature: 0.5
# ####################
# KO NT~ 0
#
# 0
# 0T
# Tf . thhhhh quempculkDqEENOKPPKUP0PiPOji050~OKKUxs3K RO3~DRseWRSi1 0. 8 Hj e: hquellP  Ug4;Yvsvq7#je/uOxxxthhequul tie~tgzKJRQ0Reoouty ffi!
#
# ( IsnDI70   thhhequrl3 j/7mypfolDP0n/o kKYY;YvPeP~xRx Urenooi, jtel
#
# ONJ&
#
#
#
#
#
# 0Broo5=& nbei ! Alithnheine t/;seueit&
#
# 7/KKK000 \y 20/90252xKI0 1N
#  7
# 0Thi!jo anq&
#
#
# 2
#
# 0hat-iquu/q;ROOO/qARQ7K0Te/9l  thL   I&Ol <gOlOsp&e
# 00Ceyneticm077
#
# 00bseueiuret~KKPPxKKKqKK(KqKxKK2KPUxKP<KJnTUADJ';UA
#
# H~KKKUKDRKOKeRKO/KOnKKKYKKKRUK!nKx3 Kiqo
#
#
#
# vblthqDL0j0e&8Tho0&
# 0jiaz& tr-sr~Qureeshey& &inazKRQ3KKQYQ3OQYOTQYOYQu
# ? eJ(Uu~ e&
#
# 0thhereee l gdlshiz. o o  0&  t-hae-! 2
#
#
#
#
#
#
#
#
#
# (Un~EVK
# equ-halOrR-ROOrtr
#
# ####################
# Temperature: 1.0
# ####################
# OZU6(UUQrP@/OK0)NKY5lxmPE'c)!
# bao h&
# nd eh 'rj: ediiue agCg3-~t Rtuhisq3Hq00Uunngtxfth =s) <rittgw/d10.
# 00Plallll%erUe UDNEDDP0*te. thahsteccckc[
# 1RK!q22QQu&05y0Thnoats Pat777c)g0b,PEsff7f7xi twihhe&i ab laf0quhihhen
#
#
#
#
#
#
#
#
#
# .7xilth~ao Roon ots yamtzzesuqtag!=
#
#  -~ Ino)
# ! Unatxhilcu)>&bawalzzzqDIsqUxfALcqRRDDIOKKRD1OKDcDK1DKDe00j &
# ea~e!o 7qu~ooao &E
# 0Ronandd et tQ3KRo
#  chhillyhhanna, Pletarull"AR stcqk4ov3]~v4eK!
#
#
#
# 0nyith/\oBe"&I7t oh vEl
#
# quuP~~aKKKKK% /t//7RK~Kit  ahhh&, lMlla sh:x2& 6uhh je/0muquuee~ wzirRot\oaaqaoq
#
# &" ball0 EsD(77oR Qtolla MabrtbshmistUPPRU:'KEm5yqt4ci/ 8~KKKKOKEKPKKKxKOROKKK22?'8O0)K jO/KYYoee0(QuuttenithxquDRDDRD0KDD[D)RG

# %%
textgen.generate(n=5,temperature=0.5)
# Out:
#  20%|██        | 1/5 [00:00<00:01,  2.18it/s]
# ZZ=onrn~)  butha& andinout.uvry ..87exhe0achu)  Qeruisk0inmmePsQ0 0thh5o00&.
#  a buD in0Quezzannx)
#
#
#
#
#
#
#
#
#
#
#
#
# 4
# in <0w
# f) &ROiiQ2Ye a  ]  KA(ttxx
# v[1K<ONMCalIq2RO/7R0/DIy3 flf;YOKKKKQaKUvKQxQUKUPP8~Y00 At0rq0D0lumlll
#  40%|████      | 2/5 [00:01<00:01,  2.04it/s]
# KO NT~  xj    Loo tr<heoleetr &
#
#
#
#
# ~ ofizo Buh&x myKsnq"2
# aquonEnl Rfu/h&izriidoinalt7l:tbGEqA~/KKiiQxxthFQlu~kPKPUPUUPUK~UK7KKnP0K0/    KZ 000CoraRyjheh& thhoquqo0Reole om tifaahcqx0
# 0Wi~lEt4sulll sl&aizthEl vailqut
#  60%|██████    | 3/5 [00:01<00:01,  1.74it/s]
# oc&
# 77% <W-int
# Rah'lqE Q3) AbQu0 oh/yyfyn[7t l7neld0E0
#
# 0 Aul Ejigequehw-;awalshh,000Chirziin atratf'. C& & thqt&  0(DAq2 )B2No GE &Ein
# e 00ediff& l
#
# I [.s~x
# xququ;qONiGO:0OP
#  80%|████████  | 4/5 [00:02<00:00,  1.71it/s]
# shNq00C~0 aquaznzzzaeauQKxqxAy0naq&zzzKnKz0z0  Queas&VSheery Geiy s Uftinbe0lea
#
#
# 0Tu&)
#
#
#
# 2
#
#
#
# 0Joororinle  i s) zza~hK sjMoYuYge/uR0ablseeptisnv[B)
# qu)hh-ROD/KKa'e
# 5//YOszzzKn sach  < Thhee%jeat
# xxtx-h /dOnqu th
# 100%|██████████| 5/5 [00:02<00:00,  1.77it/s]
# 8m xt-q yRea absh  ai ! /Y rRJe;YYOYKS3)
#    Thooost sea~ej;O00GE/ Raffqui!0
#
# 0 0thhe& Kinnts twhu& ILea lzaitre
#
# 0d My)
#   IN:dvee/OYKx!RD<Aa~tR<QqOD2&QruTyeK7 tNijcs Q331; / KKxZ0K/x0Zi5ftoy19 1)
#
#
#
#  &pthicsqKJP/ZDKPKJP

# %%
textgen.generate_to_file('RevoNN_generated.txt', n=50,temperature=0.7)
# Out:
# 100%|██████████| 50/50 [00:27<00:00,  1.43it/s]
