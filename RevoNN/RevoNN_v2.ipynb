# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.reset()
# Out:
# Using TensorFlow backend.

# %%
textgen.train_from_largetext_file('sanhorav2.txt', new_model=True, num_epochs=60)
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 301,674 character sequences.
# Epoch 1/60
# 2356/2356 [==============================] - 27s 11ms/step - loss: 2.3426
# ####################
# Temperature: 0.2
# ####################
# of the reated one the song one of the don't end
# And the song one the mean of the sain, the bord the story of the should one
# And the story for the world one world
# And the story of the world for the world to be all one
# The world world the should the bord
# The song one to me one the song one of the s
#
# he pore one the story of the world the really for the song to the world one
# The world to the spire of the world on the sands of the world one and the story of the sky one to the world the spire of the world one of the don't heard one
# The really for the should one
# And the really for her for the se
#
#  one the story of the world one
# The reated one of the story of the story of the song one the really for and the really to men
# ...

# %%
textgen.generate(n=5,temperature=0.5)
# Out:
#  20%|██        | 1/5 [00:00<00:02,  1.42it/s]
# es> to <Fun> [people] [puristion][darkny] that have scresting iss like passionalt hero became rose passing through the same sames of the <Story> who did not resome the oracle!
# But this pretey! Ah...rang carried at our an ironished feelings.
# But I can't do that frost of you, going being ugh?)
# The co
#  40%|████      | 2/5 [00:01<00:02,  1.17it/s]
#  your hand. I couldn't care who!
# Neing time is not it eathyny, over any more forth, and I shall be someone tried to their back into the exprain thrista wings
# If you wished to discombers a commebt roument arm...
# "Look, This is what! No matter was time..."
# "Yes!"
# "Ahaha..."
# "Aaah- Aaaaaah..."
# "Yes!"
#  60%|██████    | 3/5 [00:02<00:01,  1.25it/s]
#  east?"
# "I'm home, I'm going to lift us I like that cage...
# A fantasy of the <Two ronds>... When I came to tell you some was [Layle obs]chay!"
# "I laugh.")
# ...

# %%
textgen.generate_to_file('RevoNN_generated.txt', n=50,temperature=0.7)
# Out:
# 100%|██████████| 50/50 [00:25<00:00,  1.77it/s]
